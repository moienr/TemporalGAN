# %%
from utils.utils import *
from utils.ee_utils import *
from utils.utils import TextColors as tc
import ee
import geemap
from rois import ROIS
rois = ROIS()
from IPython.display import display

# %%
ee.Initialize()
Map = geemap.Map()

# %%
vis_params_s1_bright = {
    'min': -10,
    'max': 10,
    'bands': ['VV_db']
}

# %% [markdown]
# # ShowCase Examples
# this is a file that contains codes that were removed but are importat, since they were used to test some theories

# %% [markdown]
# ## High cloud cover results in false snow_cover result in sentinel 2 images
#
# For exapmle in this case, we are testing an image in summer in paris, but as you can see we are seeing a high snow/ice coverege and that is because there is a high snow covege.
#
# <span style="color: #FFFF11;">This is the reason we are not using snow removal on summer dataset anymore.</span>
#
# If you want to use snow removal, you need to <span style="color: #FF4444;">make sure that the `cloud_cover` is low in the scene.</span>
# - in our case we are using our custom cloud_cover check, which only checks our `roi`, so the whole scene could still be cloudy, and thus wrong snow_cover.

# %%
roi = rois.bercy

s2_test_col = ee.ImageCollection('COPERNICUS/S2_SR') \
                    .filterDate('2021-05-17', '2021-05-19') \
                    .filterBounds(roi)
                    
sen2_print(s2_test_col)
s2_test_img = s2_test_col.first()

scl = s2_test_img.select('SCL')
mask = scl.eq(11)

Map = geemap.Map()
Map.addLayer(s2_test_img, {'bands': ['B4', 'B3', 'B2'], 'min': 0, 'max': 3000}, 'Sentinel-2 Image', True)
Map.addLayer(mask.updateMask(mask), {'palette': 'blue'}, 'Water Mask')
Map.centerObject(roi, zoom=10)
Map.addLayerControl()
Map
# Out:
# Map(center=[48.843641547684896, 2.380256652833762], controls=(WidgetControl(options=['position', 'transparent_…

# %% [markdown]
# ## Sentinel 1A and 1B, Tandem Orbit
# sentinel 1a and 1b orbits result in a pretty simmilar, becuse of the short Spatial BaseLine.
#
# - Although I still don't know, how can you determine whether two, realtive orbit numbers are tandem or not. -> <span style="color: #FF1111; text-decoration: line-through;">More Research Needed</span>
#
# <span style="color: #11FF11;">Found The Answer - Read The Cells Below</span>

# %%
# Overwrite the default print function to for a consicise print
sen1_print = lambda s2_collection: ee_property_printer(s2_collection, propertie_name_list=['system:time_start','platform_number',
                                                                                                    'relativeOrbitNumber_start', 'orbitProperties_pass',
                                                                                                    'cycleNumber'], first_is_t_in_millis=True)

# %%
roi = rois.paris
# s2_col,s1_col = s1s2(roi,date = ('2021-07-15', '2021-08-15'),priority_path = 'DESCENDING',max_cloud = 100,max_snow = 100,month_span = 1,retry_days=0)
s1_col = ee.ImageCollection('COPERNICUS/S1_GRD') \
    .filterDate('2021-06-24', '2021-08-20') \
    .filterBounds(roi) \
    .filter(ee.Filter.eq('resolution','H')) \
    .filter(ee.Filter.eq('instrumentMode','IW'))\
    .filter(ee.Filter.contains('.geo', roi)) \
    .filterMetadata('orbitProperties_pass', 'equals', 'DESCENDING') 
    
s1_col.size().getInfo()
# Out:
# 20

# %% [markdown]
# ### Finding the most occured orbit
# well here both orbit `110` and `8` have equal passes.
# But in other cases we would like to choose images that have more passes over the roi, to get a better `spackle` mitigation.

# %%
rel_list = s1_col.aggregate_array('relativeOrbitNumber_start')
x = find_most_repeated_element(rel_list)
x
# Out:
# <div><style>:root {
#   --font-color-primary: var(--jp-content-font-color0, rgba(0, 0, 0, 1));
#   --font-color-secondary: var(--jp-content-font-color2, rgba(0, 0, 0, 0.6));
#   --font-color-accent: rgba(123, 31, 162, 1);
#   --border-color: var(--jp-border-color2, #e0e0e0);
#   --background-color: var(--jp-layout-color0, white);
#   --background-color-row-even: var(--jp-layout-color1, white);
#   --background-color-row-odd: var(--jp-layout-color2, #eeeeee);
# }
#
# html[theme="dark"],
# body[data-theme="dark"],
# body.vscode-dark {
#   --font-color-primary: rgba(255, 255, 255, 1);
#   --font-color-secondary: rgba(255, 255, 255, 0.6);
#   --font-color-accent: rgb(173, 132, 190);
#   --border-color: #2e2e2e;
#   --background-color: #111111;
#   --background-color-row-even: #111111;
#   --background-color-row-odd: #313131;
# }
#
# .ee {
#   padding: 1em;
#   line-height: 1.5em;
#   min-width: 300px;
#   max-width: 1200px;
#   overflow-y: scroll;
#   max-height: 600px;
#   border: 1px solid var(--border-color);
#   font-family: monospace;
# }
#
# .ee li {
#   list-style-type: none;
# }
#
# .ee ul {
#   padding-left: 1.5em !important;
#   margin: 0;
# }
#
# .ee > ul {
#   padding-left: 0 !important;
# }
#
# .ee-open,
# .ee-shut {
#   color: var(--font-color-secondary);
#   cursor: pointer;
#   margin: 0;
# }
#
# .ee-open:hover,
# .ee-shut:hover {
#   color: var(--font-color-primary);
# }
#
# .ee-k {
#   color: var(--font-color-accent);
#   margin-right: 6px;
# }
#
# .ee-v {
#   color: var(--font-color-primary);
# }
#
# .ee-toggle {
#   display: none;
# }
#
# .ee-shut + ul {
#   display: none;
# }
#
# .ee-open + ul {
#   display: block;
# }
#
# .ee-shut::before {
#   display: inline-block;
#   content: "▼";
#   margin-right: 6px;
#   transform: rotate(-90deg);
#   transition: transform 0.2s;
# }
#
# .ee-open::before {
#   transform: rotate(0deg);
#   display: inline-block;
#   content: "▼";
#   margin-right: 6px;
#   transition: transform 0.2s;
# }
# </style><div class='ee'><ul><li><label class='ee-shut'>[110, 8]<input type='checkbox' class='ee-toggle'></label><ul><li><span class='ee-k'>0:</span><span class='ee-v'>110</span></li><li><span class='ee-k'>1:</span><span class='ee-v'>8</span></li></ul></li></ul></div><script>function toggleHeader() {
#     const parent = this.parentElement;
#     parent.className = parent.className === "ee-open" ? "ee-shut" : "ee-open";
# }
#
# for (let c of document.getElementsByClassName("ee-toggle")) {
#     c.onclick = toggleHeader;
# }</script></div>

# %% [markdown]
# There is a pattern `BA AB BA AB BA...` with each `BA` differing only **1** day and each `BA AB` having a **5** day difference

# %%
sen1_print(s1_col.sort('system:time_start'))
# Out:
# <style type="text/css">
# #T_96655 th {
#   text-align: left;
# }
# #T_96655_row0_col0, #T_96655_row0_col1, #T_96655_row0_col2, #T_96655_row0_col3, #T_96655_row0_col4, #T_96655_row0_col5, #T_96655_row0_col6, #T_96655_row0_col7, #T_96655_row0_col8, #T_96655_row0_col9, #T_96655_row0_col10, #T_96655_row0_col11, #T_96655_row0_col12, #T_96655_row0_col13, #T_96655_row0_col14, #T_96655_row0_col15, #T_96655_row0_col16, #T_96655_row0_col17, #T_96655_row0_col18, #T_96655_row0_col19, #T_96655_row0_col20, #T_96655_row1_col0, #T_96655_row1_col1, #T_96655_row1_col2, #T_96655_row1_col3, #T_96655_row1_col4, #T_96655_row1_col5, #T_96655_row1_col6, #T_96655_row1_col7, #T_96655_row1_col8, #T_96655_row1_col9, #T_96655_row1_col10, #T_96655_row1_col11, #T_96655_row1_col12, #T_96655_row1_col13, #T_96655_row1_col14, #T_96655_row1_col15, #T_96655_row1_col16, #T_96655_row1_col17, #T_96655_row1_col18, #T_96655_row1_col19, #T_96655_row1_col20, #T_96655_row2_col0, #T_96655_row2_col1, #T_96655_row2_col2, #T_96655_row2_col3, #T_96655_row2_col4, #T_96655_row2_col5, #T_96655_row2_col6, #T_96655_row2_col7, #T_96655_row2_col8, #T_96655_row2_col9, #T_96655_row2_col10, #T_96655_row2_col11, #T_96655_row2_col12, #T_96655_row2_col13, #T_96655_row2_col14, #T_96655_row2_col15, #T_96655_row2_col16, #T_96655_row2_col17, #T_96655_row2_col18, #T_96655_row2_col19, #T_96655_row2_col20, #T_96655_row3_col0, #T_96655_row3_col1, #T_96655_row3_col2, #T_96655_row3_col3, #T_96655_row3_col4, #T_96655_row3_col5, #T_96655_row3_col6, #T_96655_row3_col7, #T_96655_row3_col8, #T_96655_row3_col9, #T_96655_row3_col10, #T_96655_row3_col11, #T_96655_row3_col12, #T_96655_row3_col13, #T_96655_row3_col14, #T_96655_row3_col15, #T_96655_row3_col16, #T_96655_row3_col17, #T_96655_row3_col18, #T_96655_row3_col19, #T_96655_row3_col20, #T_96655_row4_col0, #T_96655_row4_col1, #T_96655_row4_col2, #T_96655_row4_col3, #T_96655_row4_col4, #T_96655_row4_col5, #T_96655_row4_col6, #T_96655_row4_col7, #T_96655_row4_col8, #T_96655_row4_col9, #T_96655_row4_col10, #T_96655_row4_col11, #T_96655_row4_col12, #T_96655_row4_col13, #T_96655_row4_col14, #T_96655_row4_col15, #T_96655_row4_col16, #T_96655_row4_col17, #T_96655_row4_col18, #T_96655_row4_col19, #T_96655_row4_col20 {
#   text-align: left;
# }
# </style>
# <table id="T_96655">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_96655_level0_col0" class="col_heading level0 col0" >Property</th>
#       <th id="T_96655_level0_col1" class="col_heading level0 col1" >0</th>
#       <th id="T_96655_level0_col2" class="col_heading level0 col2" >1</th>
#       <th id="T_96655_level0_col3" class="col_heading level0 col3" >2</th>
#       <th id="T_96655_level0_col4" class="col_heading level0 col4" >3</th>
#       <th id="T_96655_level0_col5" class="col_heading level0 col5" >4</th>
#       <th id="T_96655_level0_col6" class="col_heading level0 col6" >5</th>
#       <th id="T_96655_level0_col7" class="col_heading level0 col7" >6</th>
#       <th id="T_96655_level0_col8" class="col_heading level0 col8" >7</th>
#       <th id="T_96655_level0_col9" class="col_heading level0 col9" >8</th>
#       <th id="T_96655_level0_col10" class="col_heading level0 col10" >9</th>
#       <th id="T_96655_level0_col11" class="col_heading level0 col11" >10</th>
#       <th id="T_96655_level0_col12" class="col_heading level0 col12" >11</th>
#       <th id="T_96655_level0_col13" class="col_heading level0 col13" >12</th>
#       <th id="T_96655_level0_col14" class="col_heading level0 col14" >13</th>
#       <th id="T_96655_level0_col15" class="col_heading level0 col15" >14</th>
#       <th id="T_96655_level0_col16" class="col_heading level0 col16" >15</th>
#       <th id="T_96655_level0_col17" class="col_heading level0 col17" >16</th>
#       <th id="T_96655_level0_col18" class="col_heading level0 col18" >17</th>
#       <th id="T_96655_level0_col19" class="col_heading level0 col19" >18</th>
#       <th id="T_96655_level0_col20" class="col_heading level0 col20" >19</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_96655_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_96655_row0_col0" class="data row0 col0" >system:time_start</td>
#       <td id="T_96655_row0_col1" class="data row0 col1" >2021-06-25</td>
#       <td id="T_96655_row0_col2" class="data row0 col2" >2021-06-26</td>
#       <td id="T_96655_row0_col3" class="data row0 col3" >2021-07-01</td>
#       <td id="T_96655_row0_col4" class="data row0 col4" >2021-07-02</td>
#       <td id="T_96655_row0_col5" class="data row0 col5" >2021-07-07</td>
#       <td id="T_96655_row0_col6" class="data row0 col6" >2021-07-08</td>
#       <td id="T_96655_row0_col7" class="data row0 col7" >2021-07-13</td>
#       <td id="T_96655_row0_col8" class="data row0 col8" >2021-07-14</td>
#       <td id="T_96655_row0_col9" class="data row0 col9" >2021-07-19</td>
#       <td id="T_96655_row0_col10" class="data row0 col10" >2021-07-20</td>
#       <td id="T_96655_row0_col11" class="data row0 col11" >2021-07-25</td>
#       <td id="T_96655_row0_col12" class="data row0 col12" >2021-07-26</td>
#       <td id="T_96655_row0_col13" class="data row0 col13" >2021-07-31</td>
#       <td id="T_96655_row0_col14" class="data row0 col14" >2021-08-01</td>
#       <td id="T_96655_row0_col15" class="data row0 col15" >2021-08-06</td>
#       <td id="T_96655_row0_col16" class="data row0 col16" >2021-08-07</td>
#       <td id="T_96655_row0_col17" class="data row0 col17" >2021-08-12</td>
#       <td id="T_96655_row0_col18" class="data row0 col18" >2021-08-13</td>
#       <td id="T_96655_row0_col19" class="data row0 col19" >2021-08-18</td>
#       <td id="T_96655_row0_col20" class="data row0 col20" >2021-08-19</td>
#     </tr>
#     <tr>
#       <th id="T_96655_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_96655_row1_col0" class="data row1 col0" >platform_number</td>
#       <td id="T_96655_row1_col1" class="data row1 col1" >B</td>
#       <td id="T_96655_row1_col2" class="data row1 col2" >A</td>
#       <td id="T_96655_row1_col3" class="data row1 col3" >A</td>
#       <td id="T_96655_row1_col4" class="data row1 col4" >B</td>
#       <td id="T_96655_row1_col5" class="data row1 col5" >B</td>
#       <td id="T_96655_row1_col6" class="data row1 col6" >A</td>
#       <td id="T_96655_row1_col7" class="data row1 col7" >A</td>
#       <td id="T_96655_row1_col8" class="data row1 col8" >B</td>
#       <td id="T_96655_row1_col9" class="data row1 col9" >B</td>
#       <td id="T_96655_row1_col10" class="data row1 col10" >A</td>
#       <td id="T_96655_row1_col11" class="data row1 col11" >A</td>
#       <td id="T_96655_row1_col12" class="data row1 col12" >B</td>
#       <td id="T_96655_row1_col13" class="data row1 col13" >B</td>
#       <td id="T_96655_row1_col14" class="data row1 col14" >A</td>
#       <td id="T_96655_row1_col15" class="data row1 col15" >A</td>
#       <td id="T_96655_row1_col16" class="data row1 col16" >B</td>
#       <td id="T_96655_row1_col17" class="data row1 col17" >B</td>
#       <td id="T_96655_row1_col18" class="data row1 col18" >A</td>
#       <td id="T_96655_row1_col19" class="data row1 col19" >A</td>
#       <td id="T_96655_row1_col20" class="data row1 col20" >B</td>
#     </tr>
#     <tr>
#       <th id="T_96655_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_96655_row2_col0" class="data row2 col0" >relativeOrbitNumber_start</td>
#       <td id="T_96655_row2_col1" class="data row2 col1" >8</td>
#       <td id="T_96655_row2_col2" class="data row2 col2" >110</td>
#       <td id="T_96655_row2_col3" class="data row2 col3" >8</td>
#       <td id="T_96655_row2_col4" class="data row2 col4" >110</td>
#       <td id="T_96655_row2_col5" class="data row2 col5" >8</td>
#       <td id="T_96655_row2_col6" class="data row2 col6" >110</td>
#       <td id="T_96655_row2_col7" class="data row2 col7" >8</td>
#       <td id="T_96655_row2_col8" class="data row2 col8" >110</td>
#       <td id="T_96655_row2_col9" class="data row2 col9" >8</td>
#       <td id="T_96655_row2_col10" class="data row2 col10" >110</td>
#       <td id="T_96655_row2_col11" class="data row2 col11" >8</td>

# %% [markdown]
# <span style="color: #dc0fff;">Let's devide this imageCollection, into two collections of `Only 1A` and `Only 1B`</span>
#
# Hmmm... as you can see, the `1A` collection has `two` diffrent `relativeOrbitnumber`s which mean there are two diffrent scences covering this roi, form two diffrent angles!

# %%
sen1_a =s1_col.filter(ee.Filter.eq('platform_number', 'A')).sort('system:time_start')
sen1_print(sen1_a)
# Out:
# <style type="text/css">
# #T_ab96e th {
#   text-align: left;
# }
# #T_ab96e_row0_col0, #T_ab96e_row0_col1, #T_ab96e_row0_col2, #T_ab96e_row0_col3, #T_ab96e_row0_col4, #T_ab96e_row0_col5, #T_ab96e_row0_col6, #T_ab96e_row0_col7, #T_ab96e_row0_col8, #T_ab96e_row0_col9, #T_ab96e_row0_col10, #T_ab96e_row1_col0, #T_ab96e_row1_col1, #T_ab96e_row1_col2, #T_ab96e_row1_col3, #T_ab96e_row1_col4, #T_ab96e_row1_col5, #T_ab96e_row1_col6, #T_ab96e_row1_col7, #T_ab96e_row1_col8, #T_ab96e_row1_col9, #T_ab96e_row1_col10, #T_ab96e_row2_col0, #T_ab96e_row2_col1, #T_ab96e_row2_col2, #T_ab96e_row2_col3, #T_ab96e_row2_col4, #T_ab96e_row2_col5, #T_ab96e_row2_col6, #T_ab96e_row2_col7, #T_ab96e_row2_col8, #T_ab96e_row2_col9, #T_ab96e_row2_col10, #T_ab96e_row3_col0, #T_ab96e_row3_col1, #T_ab96e_row3_col2, #T_ab96e_row3_col3, #T_ab96e_row3_col4, #T_ab96e_row3_col5, #T_ab96e_row3_col6, #T_ab96e_row3_col7, #T_ab96e_row3_col8, #T_ab96e_row3_col9, #T_ab96e_row3_col10, #T_ab96e_row4_col0, #T_ab96e_row4_col1, #T_ab96e_row4_col2, #T_ab96e_row4_col3, #T_ab96e_row4_col4, #T_ab96e_row4_col5, #T_ab96e_row4_col6, #T_ab96e_row4_col7, #T_ab96e_row4_col8, #T_ab96e_row4_col9, #T_ab96e_row4_col10 {
#   text-align: left;
# }
# </style>
# <table id="T_ab96e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ab96e_level0_col0" class="col_heading level0 col0" >Property</th>
#       <th id="T_ab96e_level0_col1" class="col_heading level0 col1" >0</th>
#       <th id="T_ab96e_level0_col2" class="col_heading level0 col2" >1</th>
#       <th id="T_ab96e_level0_col3" class="col_heading level0 col3" >2</th>
#       <th id="T_ab96e_level0_col4" class="col_heading level0 col4" >3</th>
#       <th id="T_ab96e_level0_col5" class="col_heading level0 col5" >4</th>
#       <th id="T_ab96e_level0_col6" class="col_heading level0 col6" >5</th>
#       <th id="T_ab96e_level0_col7" class="col_heading level0 col7" >6</th>
#       <th id="T_ab96e_level0_col8" class="col_heading level0 col8" >7</th>
#       <th id="T_ab96e_level0_col9" class="col_heading level0 col9" >8</th>
#       <th id="T_ab96e_level0_col10" class="col_heading level0 col10" >9</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ab96e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ab96e_row0_col0" class="data row0 col0" >system:time_start</td>
#       <td id="T_ab96e_row0_col1" class="data row0 col1" >2021-06-26</td>
#       <td id="T_ab96e_row0_col2" class="data row0 col2" >2021-07-01</td>
#       <td id="T_ab96e_row0_col3" class="data row0 col3" >2021-07-08</td>
#       <td id="T_ab96e_row0_col4" class="data row0 col4" >2021-07-13</td>
#       <td id="T_ab96e_row0_col5" class="data row0 col5" >2021-07-20</td>
#       <td id="T_ab96e_row0_col6" class="data row0 col6" >2021-07-25</td>
#       <td id="T_ab96e_row0_col7" class="data row0 col7" >2021-08-01</td>
#       <td id="T_ab96e_row0_col8" class="data row0 col8" >2021-08-06</td>
#       <td id="T_ab96e_row0_col9" class="data row0 col9" >2021-08-13</td>
#       <td id="T_ab96e_row0_col10" class="data row0 col10" >2021-08-18</td>
#     </tr>
#     <tr>
#       <th id="T_ab96e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ab96e_row1_col0" class="data row1 col0" >platform_number</td>
#       <td id="T_ab96e_row1_col1" class="data row1 col1" >A</td>
#       <td id="T_ab96e_row1_col2" class="data row1 col2" >A</td>
#       <td id="T_ab96e_row1_col3" class="data row1 col3" >A</td>
#       <td id="T_ab96e_row1_col4" class="data row1 col4" >A</td>
#       <td id="T_ab96e_row1_col5" class="data row1 col5" >A</td>
#       <td id="T_ab96e_row1_col6" class="data row1 col6" >A</td>
#       <td id="T_ab96e_row1_col7" class="data row1 col7" >A</td>
#       <td id="T_ab96e_row1_col8" class="data row1 col8" >A</td>
#       <td id="T_ab96e_row1_col9" class="data row1 col9" >A</td>
#       <td id="T_ab96e_row1_col10" class="data row1 col10" >A</td>
#     </tr>
#     <tr>
#       <th id="T_ab96e_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_ab96e_row2_col0" class="data row2 col0" >relativeOrbitNumber_start</td>
#       <td id="T_ab96e_row2_col1" class="data row2 col1" >110</td>
#       <td id="T_ab96e_row2_col2" class="data row2 col2" >8</td>
#       <td id="T_ab96e_row2_col3" class="data row2 col3" >110</td>
#       <td id="T_ab96e_row2_col4" class="data row2 col4" >8</td>
#       <td id="T_ab96e_row2_col5" class="data row2 col5" >110</td>
#       <td id="T_ab96e_row2_col6" class="data row2 col6" >8</td>
#       <td id="T_ab96e_row2_col7" class="data row2 col7" >110</td>
#       <td id="T_ab96e_row2_col8" class="data row2 col8" >8</td>
#       <td id="T_ab96e_row2_col9" class="data row2 col9" >110</td>
#       <td id="T_ab96e_row2_col10" class="data row2 col10" >8</td>
#     </tr>
#     <tr>
#       <th id="T_ab96e_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_ab96e_row3_col0" class="data row3 col0" >orbitProperties_pass</td>
#       <td id="T_ab96e_row3_col1" class="data row3 col1" >DESCENDING</td>
#       <td id="T_ab96e_row3_col2" class="data row3 col2" >DESCENDING</td>
#       <td id="T_ab96e_row3_col3" class="data row3 col3" >DESCENDING</td>
#       <td id="T_ab96e_row3_col4" class="data row3 col4" >DESCENDING</td>
#       <td id="T_ab96e_row3_col5" class="data row3 col5" >DESCENDING</td>
#       <td id="T_ab96e_row3_col6" class="data row3 col6" >DESCENDING</td>
#       <td id="T_ab96e_row3_col7" class="data row3 col7" >DESCENDING</td>
#       <td id="T_ab96e_row3_col8" class="data row3 col8" >DESCENDING</td>
#       <td id="T_ab96e_row3_col9" class="data row3 col9" >DESCENDING</td>
#       <td id="T_ab96e_row3_col10" class="data row3 col10" >DESCENDING</td>
#     </tr>
#     <tr>
#       <th id="T_ab96e_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_ab96e_row4_col0" class="data row4 col0" >cycleNumber</td>
#       <td id="T_ab96e_row4_col1" class="data row4 col1" >234</td>
#       <td id="T_ab96e_row4_col2" class="data row4 col2" >235</td>
#       <td id="T_ab96e_row4_col3" class="data row4 col3" >235</td>
#       <td id="T_ab96e_row4_col4" class="data row4 col4" >236</td>
#       <td id="T_ab96e_row4_col5" class="data row4 col5" >236</td>
#       <td id="T_ab96e_row4_col6" class="data row4 col6" >237</td>
#       <td id="T_ab96e_row4_col7" class="data row4 col7" >237</td>
#       <td id="T_ab96e_row4_col8" class="data row4 col8" >238</td>
#       <td id="T_ab96e_row4_col9" class="data row4 col9" >238</td>
#       <td id="T_ab96e_row4_col10" class="data row4 col10" >239</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Let's visualize this:

# %%
sen1a_110 = toDb(sen1_a.filter(ee.Filter.eq('relativeOrbitNumber_start', 110)).sort('system:time_start').map(toLinear).mean().clip(roi))
sen1a_8 = toDb(sen1_a.filter(ee.Filter.eq('relativeOrbitNumber_start', 8)).sort('system:time_start').map(toLinear).mean().clip(roi))
left_layer = geemap.ee_tile_layer(sen1a_110, vis_params_s1_bright, 'sen1a_110')
right_layer = geemap.ee_tile_layer(sen1a_8, vis_params_s1_bright, 'sen1a_8')
Map = geemap.Map(zoom=12)
Map.centerObject(roi)
Map.split_map(left_layer, right_layer)
Map
# Out:
# Map(center=[20, 0], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out_text…

# %% [markdown]
# ### Average Viewing angle of each Image in the roi
# Here we can see that orbit `110` has a much steeper `incident angle`, in a case where we have oribts with equal passes over the roi, we want to choose the images that have a higher incidetn angle, thus finder grain detail.

# %%
display(get_band_average(sen1a_8,'angle'),
        get_band_average(sen1a_110,'angle'))
# Out:
# <div><style>:root {
#   --font-color-primary: var(--jp-content-font-color0, rgba(0, 0, 0, 1));
#   --font-color-secondary: var(--jp-content-font-color2, rgba(0, 0, 0, 0.6));
#   --font-color-accent: rgba(123, 31, 162, 1);
#   --border-color: var(--jp-border-color2, #e0e0e0);
#   --background-color: var(--jp-layout-color0, white);
#   --background-color-row-even: var(--jp-layout-color1, white);
#   --background-color-row-odd: var(--jp-layout-color2, #eeeeee);
# }
#
# html[theme="dark"],
# body[data-theme="dark"],
# body.vscode-dark {
#   --font-color-primary: rgba(255, 255, 255, 1);
#   --font-color-secondary: rgba(255, 255, 255, 0.6);
#   --font-color-accent: rgb(173, 132, 190);
#   --border-color: #2e2e2e;
#   --background-color: #111111;
#   --background-color-row-even: #111111;
#   --background-color-row-odd: #313131;
# }
#
# .ee {
#   padding: 1em;
#   line-height: 1.5em;
#   min-width: 300px;
#   max-width: 1200px;
#   overflow-y: scroll;
#   max-height: 600px;
#   border: 1px solid var(--border-color);
#   font-family: monospace;
# }
#
# .ee li {
#   list-style-type: none;
# }
#
# .ee ul {
#   padding-left: 1.5em !important;
#   margin: 0;
# }
#
# .ee > ul {
#   padding-left: 0 !important;
# }
#
# .ee-open,
# .ee-shut {
#   color: var(--font-color-secondary);
#   cursor: pointer;
#   margin: 0;
# }
#
# .ee-open:hover,
# .ee-shut:hover {
#   color: var(--font-color-primary);
# }
#
# .ee-k {
#   color: var(--font-color-accent);
#   margin-right: 6px;
# }
#
# .ee-v {
#   color: var(--font-color-primary);
# }
#
# .ee-toggle {
#   display: none;
# }
#
# .ee-shut + ul {
#   display: none;
# }
#
# .ee-open + ul {
#   display: block;
# }
#
# .ee-shut::before {
#   display: inline-block;
#   content: "▼";
#   margin-right: 6px;
#   transform: rotate(-90deg);
#   transition: transform 0.2s;
# }
#
# .ee-open::before {
#   transform: rotate(0deg);
#   display: inline-block;
#   content: "▼";
#   margin-right: 6px;
#   transition: transform 0.2s;
# }
# </style><div class='ee'><ul><li><span class='ee-v'>31.777401400973883</span></li></ul></div><script>function toggleHeader() {
#     const parent = this.parentElement;
#     parent.className = parent.className === "ee-open" ? "ee-shut" : "ee-open";
# }
#
# for (let c of document.getElementsByClassName("ee-toggle")) {
#     c.onclick = toggleHeader;
# }</script></div>
# <div><style>:root {
#   --font-color-primary: var(--jp-content-font-color0, rgba(0, 0, 0, 1));
#   --font-color-secondary: var(--jp-content-font-color2, rgba(0, 0, 0, 0.6));
#   --font-color-accent: rgba(123, 31, 162, 1);
#   --border-color: var(--jp-border-color2, #e0e0e0);
#   --background-color: var(--jp-layout-color0, white);
#   --background-color-row-even: var(--jp-layout-color1, white);
#   --background-color-row-odd: var(--jp-layout-color2, #eeeeee);
# }
#
# html[theme="dark"],
# body[data-theme="dark"],
# body.vscode-dark {
#   --font-color-primary: rgba(255, 255, 255, 1);
#   --font-color-secondary: rgba(255, 255, 255, 0.6);
#   --font-color-accent: rgb(173, 132, 190);
#   --border-color: #2e2e2e;
#   --background-color: #111111;
#   --background-color-row-even: #111111;
#   --background-color-row-odd: #313131;
# }
#
# .ee {
#   padding: 1em;
#   line-height: 1.5em;
#   min-width: 300px;
#   max-width: 1200px;
#   overflow-y: scroll;
#   max-height: 600px;
#   border: 1px solid var(--border-color);
#   font-family: monospace;
# }
#
# .ee li {
#   list-style-type: none;
# }
#
# .ee ul {
#   padding-left: 1.5em !important;
#   margin: 0;
# }
#
# .ee > ul {
#   padding-left: 0 !important;
# }
#
# .ee-open,
# .ee-shut {
#   color: var(--font-color-secondary);
#   cursor: pointer;
#   margin: 0;
# }
#
# .ee-open:hover,
# .ee-shut:hover {
#   color: var(--font-color-primary);
# }
#
# .ee-k {
#   color: var(--font-color-accent);
#   margin-right: 6px;
# }
#
# .ee-v {
#   color: var(--font-color-primary);
# }
#
# .ee-toggle {
#   display: none;
# }
#
# .ee-shut + ul {
#   display: none;
# }
#
# .ee-open + ul {
#   display: block;
# }
#
# .ee-shut::before {
#   display: inline-block;
#   content: "▼";
#   margin-right: 6px;
#   transform: rotate(-90deg);
#   transition: transform 0.2s;
# }
#
# .ee-open::before {
#   transform: rotate(0deg);
#   display: inline-block;
#   content: "▼";
#   margin-right: 6px;
#   transition: transform 0.2s;
# }
# </style><div class='ee'><ul><li><span class='ee-v'>41.16627866713624</span></li></ul></div><script>function toggleHeader() {
#     const parent = this.parentElement;
#     parent.className = parent.className === "ee-open" ? "ee-shut" : "ee-open";
# }
#
# for (let c of document.getElementsByClassName("ee-toggle")) {
#     c.onclick = toggleHeader;
# }</script></div>

# %% [markdown]
# We can also see that `sentinel-1b`, of the same orbits have almost `the same` incident angle as `1a`

# %%
sen1_b =s1_col.filter(ee.Filter.eq('platform_number', 'B')).sort('system:time_start')
sen1b_110 = toDb(sen1_a.filter(ee.Filter.eq('relativeOrbitNumber_start', 110)).sort('system:time_start').map(toLinear).mean().clip(roi))
sen1b_8 = toDb(sen1_a.filter(ee.Filter.eq('relativeOrbitNumber_start', 8)).sort('system:time_start').map(toLinear).mean().clip(roi))
display(get_band_average(sen1b_8,'angle'),
        get_band_average(sen1b_110,'angle'))
# Out:
# <div><style>:root {
#   --font-color-primary: var(--jp-content-font-color0, rgba(0, 0, 0, 1));
#   --font-color-secondary: var(--jp-content-font-color2, rgba(0, 0, 0, 0.6));
#   --font-color-accent: rgba(123, 31, 162, 1);
#   --border-color: var(--jp-border-color2, #e0e0e0);
#   --background-color: var(--jp-layout-color0, white);
#   --background-color-row-even: var(--jp-layout-color1, white);
#   --background-color-row-odd: var(--jp-layout-color2, #eeeeee);
# }
#
# html[theme="dark"],
# body[data-theme="dark"],
# body.vscode-dark {
#   --font-color-primary: rgba(255, 255, 255, 1);
#   --font-color-secondary: rgba(255, 255, 255, 0.6);
#   --font-color-accent: rgb(173, 132, 190);
#   --border-color: #2e2e2e;
#   --background-color: #111111;
#   --background-color-row-even: #111111;
#   --background-color-row-odd: #313131;
# }
#
# .ee {
#   padding: 1em;
#   line-height: 1.5em;
#   min-width: 300px;
#   max-width: 1200px;
#   overflow-y: scroll;
#   max-height: 600px;
#   border: 1px solid var(--border-color);
#   font-family: monospace;
# }
#
# .ee li {
#   list-style-type: none;
# }
#
# .ee ul {
#   padding-left: 1.5em !important;
#   margin: 0;
# }
#
# .ee > ul {
#   padding-left: 0 !important;
# }
#
# .ee-open,
# .ee-shut {
#   color: var(--font-color-secondary);
#   cursor: pointer;
#   margin: 0;
# }
#
# .ee-open:hover,
# .ee-shut:hover {
#   color: var(--font-color-primary);
# }
#
# .ee-k {
#   color: var(--font-color-accent);
#   margin-right: 6px;
# }
#
# .ee-v {
#   color: var(--font-color-primary);
# }
#
# .ee-toggle {
#   display: none;
# }
#
# .ee-shut + ul {
#   display: none;
# }
#
# .ee-open + ul {
#   display: block;
# }
#
# .ee-shut::before {
#   display: inline-block;
#   content: "▼";
#   margin-right: 6px;
#   transform: rotate(-90deg);
#   transition: transform 0.2s;
# }
#
# .ee-open::before {
#   transform: rotate(0deg);
#   display: inline-block;
#   content: "▼";
#   margin-right: 6px;
#   transition: transform 0.2s;
# }
# </style><div class='ee'><ul><li><span class='ee-v'>31.777401400973883</span></li></ul></div><script>function toggleHeader() {
#     const parent = this.parentElement;
#     parent.className = parent.className === "ee-open" ? "ee-shut" : "ee-open";
# }
#
# for (let c of document.getElementsByClassName("ee-toggle")) {
#     c.onclick = toggleHeader;
# }</script></div>
# <div><style>:root {
#   --font-color-primary: var(--jp-content-font-color0, rgba(0, 0, 0, 1));
#   --font-color-secondary: var(--jp-content-font-color2, rgba(0, 0, 0, 0.6));
#   --font-color-accent: rgba(123, 31, 162, 1);
#   --border-color: var(--jp-border-color2, #e0e0e0);
#   --background-color: var(--jp-layout-color0, white);
#   --background-color-row-even: var(--jp-layout-color1, white);
#   --background-color-row-odd: var(--jp-layout-color2, #eeeeee);
# }
#
# html[theme="dark"],
# body[data-theme="dark"],
# body.vscode-dark {
#   --font-color-primary: rgba(255, 255, 255, 1);
#   --font-color-secondary: rgba(255, 255, 255, 0.6);
#   --font-color-accent: rgb(173, 132, 190);
#   --border-color: #2e2e2e;
#   --background-color: #111111;
#   --background-color-row-even: #111111;
#   --background-color-row-odd: #313131;
# }
#
# .ee {
#   padding: 1em;
#   line-height: 1.5em;
#   min-width: 300px;
#   max-width: 1200px;
#   overflow-y: scroll;
#   max-height: 600px;
#   border: 1px solid var(--border-color);
#   font-family: monospace;
# }
#
# .ee li {
#   list-style-type: none;
# }
#
# .ee ul {
#   padding-left: 1.5em !important;
#   margin: 0;
# }
#
# .ee > ul {
#   padding-left: 0 !important;
# }
#
# .ee-open,
# .ee-shut {
#   color: var(--font-color-secondary);
#   cursor: pointer;
#   margin: 0;
# }
#
# .ee-open:hover,
# .ee-shut:hover {
#   color: var(--font-color-primary);
# }
#
# .ee-k {
#   color: var(--font-color-accent);
#   margin-right: 6px;
# }
#
# .ee-v {
#   color: var(--font-color-primary);
# }
#
# .ee-toggle {
#   display: none;
# }
#
# .ee-shut + ul {
#   display: none;
# }
#
# .ee-open + ul {
#   display: block;
# }
#
# .ee-shut::before {
#   display: inline-block;
#   content: "▼";
#   margin-right: 6px;
#   transform: rotate(-90deg);
#   transition: transform 0.2s;
# }
#
# .ee-open::before {
#   transform: rotate(0deg);
#   display: inline-block;
#   content: "▼";
#   margin-right: 6px;
#   transition: transform 0.2s;
# }
# </style><div class='ee'><ul><li><span class='ee-v'>41.16627866713624</span></li></ul></div><script>function toggleHeader() {
#     const parent = this.parentElement;
#     parent.className = parent.className === "ee-open" ? "ee-shut" : "ee-open";
# }
#
# for (let c of document.getElementsByClassName("ee-toggle")) {
#     c.onclick = toggleHeader;
# }</script></div>

# %% [markdown]
# The same for 1B

# %%
sen1_print(s1_col.filter(ee.Filter.eq('platform_number', 'B')).sort('system:time_start'))
# Out:
# <style type="text/css">
# #T_2e3b6 th {
#   text-align: left;
# }
# #T_2e3b6_row0_col0, #T_2e3b6_row0_col1, #T_2e3b6_row0_col2, #T_2e3b6_row0_col3, #T_2e3b6_row0_col4, #T_2e3b6_row0_col5, #T_2e3b6_row0_col6, #T_2e3b6_row0_col7, #T_2e3b6_row0_col8, #T_2e3b6_row0_col9, #T_2e3b6_row0_col10, #T_2e3b6_row1_col0, #T_2e3b6_row1_col1, #T_2e3b6_row1_col2, #T_2e3b6_row1_col3, #T_2e3b6_row1_col4, #T_2e3b6_row1_col5, #T_2e3b6_row1_col6, #T_2e3b6_row1_col7, #T_2e3b6_row1_col8, #T_2e3b6_row1_col9, #T_2e3b6_row1_col10, #T_2e3b6_row2_col0, #T_2e3b6_row2_col1, #T_2e3b6_row2_col2, #T_2e3b6_row2_col3, #T_2e3b6_row2_col4, #T_2e3b6_row2_col5, #T_2e3b6_row2_col6, #T_2e3b6_row2_col7, #T_2e3b6_row2_col8, #T_2e3b6_row2_col9, #T_2e3b6_row2_col10, #T_2e3b6_row3_col0, #T_2e3b6_row3_col1, #T_2e3b6_row3_col2, #T_2e3b6_row3_col3, #T_2e3b6_row3_col4, #T_2e3b6_row3_col5, #T_2e3b6_row3_col6, #T_2e3b6_row3_col7, #T_2e3b6_row3_col8, #T_2e3b6_row3_col9, #T_2e3b6_row3_col10, #T_2e3b6_row4_col0, #T_2e3b6_row4_col1, #T_2e3b6_row4_col2, #T_2e3b6_row4_col3, #T_2e3b6_row4_col4, #T_2e3b6_row4_col5, #T_2e3b6_row4_col6, #T_2e3b6_row4_col7, #T_2e3b6_row4_col8, #T_2e3b6_row4_col9, #T_2e3b6_row4_col10 {
#   text-align: left;
# }
# </style>
# <table id="T_2e3b6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2e3b6_level0_col0" class="col_heading level0 col0" >Property</th>
#       <th id="T_2e3b6_level0_col1" class="col_heading level0 col1" >0</th>
#       <th id="T_2e3b6_level0_col2" class="col_heading level0 col2" >1</th>
#       <th id="T_2e3b6_level0_col3" class="col_heading level0 col3" >2</th>
#       <th id="T_2e3b6_level0_col4" class="col_heading level0 col4" >3</th>
#       <th id="T_2e3b6_level0_col5" class="col_heading level0 col5" >4</th>
#       <th id="T_2e3b6_level0_col6" class="col_heading level0 col6" >5</th>
#       <th id="T_2e3b6_level0_col7" class="col_heading level0 col7" >6</th>
#       <th id="T_2e3b6_level0_col8" class="col_heading level0 col8" >7</th>
#       <th id="T_2e3b6_level0_col9" class="col_heading level0 col9" >8</th>
#       <th id="T_2e3b6_level0_col10" class="col_heading level0 col10" >9</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2e3b6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2e3b6_row0_col0" class="data row0 col0" >system:time_start</td>
#       <td id="T_2e3b6_row0_col1" class="data row0 col1" >2021-06-25</td>
#       <td id="T_2e3b6_row0_col2" class="data row0 col2" >2021-07-02</td>
#       <td id="T_2e3b6_row0_col3" class="data row0 col3" >2021-07-07</td>
#       <td id="T_2e3b6_row0_col4" class="data row0 col4" >2021-07-14</td>
#       <td id="T_2e3b6_row0_col5" class="data row0 col5" >2021-07-19</td>
#       <td id="T_2e3b6_row0_col6" class="data row0 col6" >2021-07-26</td>
#       <td id="T_2e3b6_row0_col7" class="data row0 col7" >2021-07-31</td>
#       <td id="T_2e3b6_row0_col8" class="data row0 col8" >2021-08-07</td>
#       <td id="T_2e3b6_row0_col9" class="data row0 col9" >2021-08-12</td>
#       <td id="T_2e3b6_row0_col10" class="data row0 col10" >2021-08-19</td>
#     </tr>
#     <tr>
#       <th id="T_2e3b6_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_2e3b6_row1_col0" class="data row1 col0" >platform_number</td>
#       <td id="T_2e3b6_row1_col1" class="data row1 col1" >B</td>
#       <td id="T_2e3b6_row1_col2" class="data row1 col2" >B</td>
#       <td id="T_2e3b6_row1_col3" class="data row1 col3" >B</td>
#       <td id="T_2e3b6_row1_col4" class="data row1 col4" >B</td>
#       <td id="T_2e3b6_row1_col5" class="data row1 col5" >B</td>
#       <td id="T_2e3b6_row1_col6" class="data row1 col6" >B</td>
#       <td id="T_2e3b6_row1_col7" class="data row1 col7" >B</td>
#       <td id="T_2e3b6_row1_col8" class="data row1 col8" >B</td>
#       <td id="T_2e3b6_row1_col9" class="data row1 col9" >B</td>
#       <td id="T_2e3b6_row1_col10" class="data row1 col10" >B</td>
#     </tr>
#     <tr>
#       <th id="T_2e3b6_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_2e3b6_row2_col0" class="data row2 col0" >relativeOrbitNumber_start</td>
#       <td id="T_2e3b6_row2_col1" class="data row2 col1" >8</td>
#       <td id="T_2e3b6_row2_col2" class="data row2 col2" >110</td>
#       <td id="T_2e3b6_row2_col3" class="data row2 col3" >8</td>
#       <td id="T_2e3b6_row2_col4" class="data row2 col4" >110</td>
#       <td id="T_2e3b6_row2_col5" class="data row2 col5" >8</td>
#       <td id="T_2e3b6_row2_col6" class="data row2 col6" >110</td>
#       <td id="T_2e3b6_row2_col7" class="data row2 col7" >8</td>
#       <td id="T_2e3b6_row2_col8" class="data row2 col8" >110</td>
#       <td id="T_2e3b6_row2_col9" class="data row2 col9" >8</td>
#       <td id="T_2e3b6_row2_col10" class="data row2 col10" >110</td>
#     </tr>
#     <tr>
#       <th id="T_2e3b6_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_2e3b6_row3_col0" class="data row3 col0" >orbitProperties_pass</td>
#       <td id="T_2e3b6_row3_col1" class="data row3 col1" >DESCENDING</td>
#       <td id="T_2e3b6_row3_col2" class="data row3 col2" >DESCENDING</td>
#       <td id="T_2e3b6_row3_col3" class="data row3 col3" >DESCENDING</td>
#       <td id="T_2e3b6_row3_col4" class="data row3 col4" >DESCENDING</td>
#       <td id="T_2e3b6_row3_col5" class="data row3 col5" >DESCENDING</td>
#       <td id="T_2e3b6_row3_col6" class="data row3 col6" >DESCENDING</td>
#       <td id="T_2e3b6_row3_col7" class="data row3 col7" >DESCENDING</td>
#       <td id="T_2e3b6_row3_col8" class="data row3 col8" >DESCENDING</td>
#       <td id="T_2e3b6_row3_col9" class="data row3 col9" >DESCENDING</td>
#       <td id="T_2e3b6_row3_col10" class="data row3 col10" >DESCENDING</td>
#     </tr>
#     <tr>
#       <th id="T_2e3b6_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_2e3b6_row4_col0" class="data row4 col0" >cycleNumber</td>
#       <td id="T_2e3b6_row4_col1" class="data row4 col1" >164</td>
#       <td id="T_2e3b6_row4_col2" class="data row4 col2" >164</td>
#       <td id="T_2e3b6_row4_col3" class="data row4 col3" >165</td>
#       <td id="T_2e3b6_row4_col4" class="data row4 col4" >165</td>
#       <td id="T_2e3b6_row4_col5" class="data row4 col5" >166</td>
#       <td id="T_2e3b6_row4_col6" class="data row4 col6" >166</td>
#       <td id="T_2e3b6_row4_col7" class="data row4 col7" >167</td>
#       <td id="T_2e3b6_row4_col8" class="data row4 col8" >167</td>
#       <td id="T_2e3b6_row4_col9" class="data row4 col9" >168</td>
#       <td id="T_2e3b6_row4_col10" class="data row4 col10" >168</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Let's deivde them by Oribt Number
# `1A` and `1B` have the same Orbit Number over an Area!
# - This is the Tandem Orbit
# - So for consistat viewing geometry, filter by orbit number

# %%
print(tc.BOLD,'Relative orbit number 8: ',tc.ENDC)
sen1_print(s1_col.filter(ee.Filter.eq('relativeOrbitNumber_start', ee.Number(8))).sort('system:time_start'))
# Out:
#  Relative orbit number 8:
# <style type="text/css">
# #T_23fbc th {
#   text-align: left;
# }
# #T_23fbc_row0_col0, #T_23fbc_row0_col1, #T_23fbc_row0_col2, #T_23fbc_row0_col3, #T_23fbc_row0_col4, #T_23fbc_row0_col5, #T_23fbc_row0_col6, #T_23fbc_row0_col7, #T_23fbc_row0_col8, #T_23fbc_row0_col9, #T_23fbc_row0_col10, #T_23fbc_row1_col0, #T_23fbc_row1_col1, #T_23fbc_row1_col2, #T_23fbc_row1_col3, #T_23fbc_row1_col4, #T_23fbc_row1_col5, #T_23fbc_row1_col6, #T_23fbc_row1_col7, #T_23fbc_row1_col8, #T_23fbc_row1_col9, #T_23fbc_row1_col10, #T_23fbc_row2_col0, #T_23fbc_row2_col1, #T_23fbc_row2_col2, #T_23fbc_row2_col3, #T_23fbc_row2_col4, #T_23fbc_row2_col5, #T_23fbc_row2_col6, #T_23fbc_row2_col7, #T_23fbc_row2_col8, #T_23fbc_row2_col9, #T_23fbc_row2_col10, #T_23fbc_row3_col0, #T_23fbc_row3_col1, #T_23fbc_row3_col2, #T_23fbc_row3_col3, #T_23fbc_row3_col4, #T_23fbc_row3_col5, #T_23fbc_row3_col6, #T_23fbc_row3_col7, #T_23fbc_row3_col8, #T_23fbc_row3_col9, #T_23fbc_row3_col10, #T_23fbc_row4_col0, #T_23fbc_row4_col1, #T_23fbc_row4_col2, #T_23fbc_row4_col3, #T_23fbc_row4_col4, #T_23fbc_row4_col5, #T_23fbc_row4_col6, #T_23fbc_row4_col7, #T_23fbc_row4_col8, #T_23fbc_row4_col9, #T_23fbc_row4_col10 {
#   text-align: left;
# }
# </style>
# <table id="T_23fbc">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_23fbc_level0_col0" class="col_heading level0 col0" >Property</th>
#       <th id="T_23fbc_level0_col1" class="col_heading level0 col1" >0</th>
#       <th id="T_23fbc_level0_col2" class="col_heading level0 col2" >1</th>
#       <th id="T_23fbc_level0_col3" class="col_heading level0 col3" >2</th>
#       <th id="T_23fbc_level0_col4" class="col_heading level0 col4" >3</th>
#       <th id="T_23fbc_level0_col5" class="col_heading level0 col5" >4</th>
#       <th id="T_23fbc_level0_col6" class="col_heading level0 col6" >5</th>
#       <th id="T_23fbc_level0_col7" class="col_heading level0 col7" >6</th>
#       <th id="T_23fbc_level0_col8" class="col_heading level0 col8" >7</th>
#       <th id="T_23fbc_level0_col9" class="col_heading level0 col9" >8</th>
#       <th id="T_23fbc_level0_col10" class="col_heading level0 col10" >9</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_23fbc_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_23fbc_row0_col0" class="data row0 col0" >system:time_start</td>
#       <td id="T_23fbc_row0_col1" class="data row0 col1" >2021-06-25</td>
#       <td id="T_23fbc_row0_col2" class="data row0 col2" >2021-07-01</td>
#       <td id="T_23fbc_row0_col3" class="data row0 col3" >2021-07-07</td>
#       <td id="T_23fbc_row0_col4" class="data row0 col4" >2021-07-13</td>
#       <td id="T_23fbc_row0_col5" class="data row0 col5" >2021-07-19</td>
#       <td id="T_23fbc_row0_col6" class="data row0 col6" >2021-07-25</td>
#       <td id="T_23fbc_row0_col7" class="data row0 col7" >2021-07-31</td>
#       <td id="T_23fbc_row0_col8" class="data row0 col8" >2021-08-06</td>
#       <td id="T_23fbc_row0_col9" class="data row0 col9" >2021-08-12</td>
#       <td id="T_23fbc_row0_col10" class="data row0 col10" >2021-08-18</td>
#     </tr>
#     <tr>
#       <th id="T_23fbc_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_23fbc_row1_col0" class="data row1 col0" >platform_number</td>
#       <td id="T_23fbc_row1_col1" class="data row1 col1" >B</td>
#       <td id="T_23fbc_row1_col2" class="data row1 col2" >A</td>
#       <td id="T_23fbc_row1_col3" class="data row1 col3" >B</td>
#       <td id="T_23fbc_row1_col4" class="data row1 col4" >A</td>
#       <td id="T_23fbc_row1_col5" class="data row1 col5" >B</td>
#       <td id="T_23fbc_row1_col6" class="data row1 col6" >A</td>
#       <td id="T_23fbc_row1_col7" class="data row1 col7" >B</td>
#       <td id="T_23fbc_row1_col8" class="data row1 col8" >A</td>
#       <td id="T_23fbc_row1_col9" class="data row1 col9" >B</td>
#       <td id="T_23fbc_row1_col10" class="data row1 col10" >A</td>
#     </tr>
#     <tr>
#       <th id="T_23fbc_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_23fbc_row2_col0" class="data row2 col0" >relativeOrbitNumber_start</td>
#       <td id="T_23fbc_row2_col1" class="data row2 col1" >8</td>
#       <td id="T_23fbc_row2_col2" class="data row2 col2" >8</td>
#       <td id="T_23fbc_row2_col3" class="data row2 col3" >8</td>
#       <td id="T_23fbc_row2_col4" class="data row2 col4" >8</td>
#       <td id="T_23fbc_row2_col5" class="data row2 col5" >8</td>
#       <td id="T_23fbc_row2_col6" class="data row2 col6" >8</td>
#       <td id="T_23fbc_row2_col7" class="data row2 col7" >8</td>
#       <td id="T_23fbc_row2_col8" class="data row2 col8" >8</td>
#       <td id="T_23fbc_row2_col9" class="data row2 col9" >8</td>
#       <td id="T_23fbc_row2_col10" class="data row2 col10" >8</td>
#     </tr>
#     <tr>
#       <th id="T_23fbc_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_23fbc_row3_col0" class="data row3 col0" >orbitProperties_pass</td>
#       <td id="T_23fbc_row3_col1" class="data row3 col1" >DESCENDING</td>
#       <td id="T_23fbc_row3_col2" class="data row3 col2" >DESCENDING</td>
#       <td id="T_23fbc_row3_col3" class="data row3 col3" >DESCENDING</td>
#       <td id="T_23fbc_row3_col4" class="data row3 col4" >DESCENDING</td>
#       <td id="T_23fbc_row3_col5" class="data row3 col5" >DESCENDING</td>
#       <td id="T_23fbc_row3_col6" class="data row3 col6" >DESCENDING</td>
#       <td id="T_23fbc_row3_col7" class="data row3 col7" >DESCENDING</td>
#       <td id="T_23fbc_row3_col8" class="data row3 col8" >DESCENDING</td>
#       <td id="T_23fbc_row3_col9" class="data row3 col9" >DESCENDING</td>
#       <td id="T_23fbc_row3_col10" class="data row3 col10" >DESCENDING</td>
#     </tr>
#     <tr>
#       <th id="T_23fbc_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_23fbc_row4_col0" class="data row4 col0" >cycleNumber</td>
#       <td id="T_23fbc_row4_col1" class="data row4 col1" >164</td>
#       <td id="T_23fbc_row4_col2" class="data row4 col2" >235</td>
#       <td id="T_23fbc_row4_col3" class="data row4 col3" >165</td>
#       <td id="T_23fbc_row4_col4" class="data row4 col4" >236</td>
#       <td id="T_23fbc_row4_col5" class="data row4 col5" >166</td>
#       <td id="T_23fbc_row4_col6" class="data row4 col6" >237</td>
#       <td id="T_23fbc_row4_col7" class="data row4 col7" >167</td>
#       <td id="T_23fbc_row4_col8" class="data row4 col8" >238</td>
#       <td id="T_23fbc_row4_col9" class="data row4 col9" >168</td>
#       <td id="T_23fbc_row4_col10" class="data row4 col10" >239</td>
#     </tr>
#   </tbody>
# </table>

# %%
print(tc.BOLD,'Relative orbit number 110: ',tc.ENDC)
sen1_print(s1_col.filter(ee.Filter.eq('relativeOrbitNumber_start', ee.Number(110))).sort('system:time_start'))
# Out:
#  Relative orbit number 110:
# <style type="text/css">
# #T_d70f1 th {
#   text-align: left;
# }
# #T_d70f1_row0_col0, #T_d70f1_row0_col1, #T_d70f1_row0_col2, #T_d70f1_row0_col3, #T_d70f1_row0_col4, #T_d70f1_row0_col5, #T_d70f1_row0_col6, #T_d70f1_row0_col7, #T_d70f1_row0_col8, #T_d70f1_row0_col9, #T_d70f1_row0_col10, #T_d70f1_row1_col0, #T_d70f1_row1_col1, #T_d70f1_row1_col2, #T_d70f1_row1_col3, #T_d70f1_row1_col4, #T_d70f1_row1_col5, #T_d70f1_row1_col6, #T_d70f1_row1_col7, #T_d70f1_row1_col8, #T_d70f1_row1_col9, #T_d70f1_row1_col10, #T_d70f1_row2_col0, #T_d70f1_row2_col1, #T_d70f1_row2_col2, #T_d70f1_row2_col3, #T_d70f1_row2_col4, #T_d70f1_row2_col5, #T_d70f1_row2_col6, #T_d70f1_row2_col7, #T_d70f1_row2_col8, #T_d70f1_row2_col9, #T_d70f1_row2_col10, #T_d70f1_row3_col0, #T_d70f1_row3_col1, #T_d70f1_row3_col2, #T_d70f1_row3_col3, #T_d70f1_row3_col4, #T_d70f1_row3_col5, #T_d70f1_row3_col6, #T_d70f1_row3_col7, #T_d70f1_row3_col8, #T_d70f1_row3_col9, #T_d70f1_row3_col10, #T_d70f1_row4_col0, #T_d70f1_row4_col1, #T_d70f1_row4_col2, #T_d70f1_row4_col3, #T_d70f1_row4_col4, #T_d70f1_row4_col5, #T_d70f1_row4_col6, #T_d70f1_row4_col7, #T_d70f1_row4_col8, #T_d70f1_row4_col9, #T_d70f1_row4_col10 {
#   text-align: left;
# }
# </style>
# <table id="T_d70f1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d70f1_level0_col0" class="col_heading level0 col0" >Property</th>
#       <th id="T_d70f1_level0_col1" class="col_heading level0 col1" >0</th>
#       <th id="T_d70f1_level0_col2" class="col_heading level0 col2" >1</th>
#       <th id="T_d70f1_level0_col3" class="col_heading level0 col3" >2</th>
#       <th id="T_d70f1_level0_col4" class="col_heading level0 col4" >3</th>
#       <th id="T_d70f1_level0_col5" class="col_heading level0 col5" >4</th>
#       <th id="T_d70f1_level0_col6" class="col_heading level0 col6" >5</th>
#       <th id="T_d70f1_level0_col7" class="col_heading level0 col7" >6</th>
#       <th id="T_d70f1_level0_col8" class="col_heading level0 col8" >7</th>
#       <th id="T_d70f1_level0_col9" class="col_heading level0 col9" >8</th>
#       <th id="T_d70f1_level0_col10" class="col_heading level0 col10" >9</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d70f1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d70f1_row0_col0" class="data row0 col0" >system:time_start</td>
#       <td id="T_d70f1_row0_col1" class="data row0 col1" >2021-06-26</td>
#       <td id="T_d70f1_row0_col2" class="data row0 col2" >2021-07-02</td>
#       <td id="T_d70f1_row0_col3" class="data row0 col3" >2021-07-08</td>
#       <td id="T_d70f1_row0_col4" class="data row0 col4" >2021-07-14</td>
#       <td id="T_d70f1_row0_col5" class="data row0 col5" >2021-07-20</td>
#       <td id="T_d70f1_row0_col6" class="data row0 col6" >2021-07-26</td>
#       <td id="T_d70f1_row0_col7" class="data row0 col7" >2021-08-01</td>
#       <td id="T_d70f1_row0_col8" class="data row0 col8" >2021-08-07</td>
#       <td id="T_d70f1_row0_col9" class="data row0 col9" >2021-08-13</td>
#       <td id="T_d70f1_row0_col10" class="data row0 col10" >2021-08-19</td>
#     </tr>
#     <tr>
#       <th id="T_d70f1_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d70f1_row1_col0" class="data row1 col0" >platform_number</td>
#       <td id="T_d70f1_row1_col1" class="data row1 col1" >A</td>
#       <td id="T_d70f1_row1_col2" class="data row1 col2" >B</td>
#       <td id="T_d70f1_row1_col3" class="data row1 col3" >A</td>
#       <td id="T_d70f1_row1_col4" class="data row1 col4" >B</td>
#       <td id="T_d70f1_row1_col5" class="data row1 col5" >A</td>
#       <td id="T_d70f1_row1_col6" class="data row1 col6" >B</td>
#       <td id="T_d70f1_row1_col7" class="data row1 col7" >A</td>
#       <td id="T_d70f1_row1_col8" class="data row1 col8" >B</td>
#       <td id="T_d70f1_row1_col9" class="data row1 col9" >A</td>
#       <td id="T_d70f1_row1_col10" class="data row1 col10" >B</td>
#     </tr>
#     <tr>
#       <th id="T_d70f1_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d70f1_row2_col0" class="data row2 col0" >relativeOrbitNumber_start</td>
#       <td id="T_d70f1_row2_col1" class="data row2 col1" >110</td>
#       <td id="T_d70f1_row2_col2" class="data row2 col2" >110</td>
#       <td id="T_d70f1_row2_col3" class="data row2 col3" >110</td>
#       <td id="T_d70f1_row2_col4" class="data row2 col4" >110</td>
#       <td id="T_d70f1_row2_col5" class="data row2 col5" >110</td>
#       <td id="T_d70f1_row2_col6" class="data row2 col6" >110</td>
#       <td id="T_d70f1_row2_col7" class="data row2 col7" >110</td>
#       <td id="T_d70f1_row2_col8" class="data row2 col8" >110</td>
#       <td id="T_d70f1_row2_col9" class="data row2 col9" >110</td>
#       <td id="T_d70f1_row2_col10" class="data row2 col10" >110</td>
#     </tr>
#     <tr>
#       <th id="T_d70f1_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d70f1_row3_col0" class="data row3 col0" >orbitProperties_pass</td>
#       <td id="T_d70f1_row3_col1" class="data row3 col1" >DESCENDING</td>
#       <td id="T_d70f1_row3_col2" class="data row3 col2" >DESCENDING</td>
#       <td id="T_d70f1_row3_col3" class="data row3 col3" >DESCENDING</td>
#       <td id="T_d70f1_row3_col4" class="data row3 col4" >DESCENDING</td>
#       <td id="T_d70f1_row3_col5" class="data row3 col5" >DESCENDING</td>
#       <td id="T_d70f1_row3_col6" class="data row3 col6" >DESCENDING</td>
#       <td id="T_d70f1_row3_col7" class="data row3 col7" >DESCENDING</td>
#       <td id="T_d70f1_row3_col8" class="data row3 col8" >DESCENDING</td>
#       <td id="T_d70f1_row3_col9" class="data row3 col9" >DESCENDING</td>
#       <td id="T_d70f1_row3_col10" class="data row3 col10" >DESCENDING</td>
#     </tr>
#     <tr>
#       <th id="T_d70f1_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_d70f1_row4_col0" class="data row4 col0" >cycleNumber</td>
#       <td id="T_d70f1_row4_col1" class="data row4 col1" >234</td>
#       <td id="T_d70f1_row4_col2" class="data row4 col2" >164</td>
#       <td id="T_d70f1_row4_col3" class="data row4 col3" >235</td>
#       <td id="T_d70f1_row4_col4" class="data row4 col4" >165</td>
#       <td id="T_d70f1_row4_col5" class="data row4 col5" >236</td>
#       <td id="T_d70f1_row4_col6" class="data row4 col6" >166</td>
#       <td id="T_d70f1_row4_col7" class="data row4 col7" >237</td>
#       <td id="T_d70f1_row4_col8" class="data row4 col8" >167</td>
#       <td id="T_d70f1_row4_col9" class="data row4 col9" >238</td>
#       <td id="T_d70f1_row4_col10" class="data row4 col10" >168</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Comparing 1A and 1B on the same Orbit
# lest filter the collection by only `orbit==8`, and then devide it into `1A` and `1B`

# %%
s1_col_8 = s1_col.filter(ee.Filter.eq('relativeOrbitNumber_start', ee.Number(8))).sort('system:time_start').map(toLinear)

# %%
s1a = toDb(s1_col_8.filter(ee.Filter.eq('platform_number', 'A')).mean().clip(roi))
s1b = toDb(s1_col_8.filter(ee.Filter.eq('platform_number', 'B')).mean().clip(roi))
left_layer = geemap.ee_tile_layer(s1a, vis_params_s1_bright, 'S1a')
right_layer = geemap.ee_tile_layer(s1b, vis_params_s1_bright, 'S1b')

# %% [markdown]
# <span style="color: #11FF11;">The Diffrence is a lot Less!</span>
#
# - Corner reflectors stay a corner reflector! unlike diffrent orbits, these are `directional corner reflectors` the since the the dirrection in orbits change they might be a CR in one of them and not in the other!
#
# - The spacle is higher since we devided the collection both by `A` and `B` and `relativeOrbit`
#
# But we made out point!
#
# Which  is: <span style="font-weight: bold; color: red;">USE ONLY ONE ORBIT</span>.

# %%
Map = geemap.Map(zoom=12)
Map.centerObject(roi)
Map.split_map(left_layer, right_layer)
Map
# Out:
# Map(center=[20, 0], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out_text…

# %% [markdown]
# ## Viewing Angle

# %%
# Define an area of interest (AOI)
aoi = ee.Geometry.Point([-122.4439, 37.7538])

# Load the Sentinel-1 data collection
sentinel1 = ee.ImageCollection('COPERNICUS/S1_GRD') \
    .filterBounds(aoi) \
    .filterDate('2022-01-01', '2022-01-31') \
    .first()

# Select the 'angle' band
angle = sentinel1.select('angle')

# Define the visualization parameters
vis_params = {
    'min': 25,
    'max': 45,
    'palette': ['white', 'red']
}

# Display the image using geemap
Map = geemap.Map(center=[37.7538, -122.4439], zoom=10)
Map.addLayer(angle, vis_params, 'Angle')
#Map.addLayerControl()
#Map.setControlVisibility(layer_control=True, fullscreen_control=True, lat_lng_popup=True)
Map
# Out:
# Map(center=[37.7538, -122.4439], controls=(WidgetControl(options=['position', 'transparent_bg'], widget=HBox(c…

# %% [markdown]
# # Usage of new s1s2 funciton

# %%
s2_col,s1_col = s1s2(roi,date = ('2021-07-15', '2021-08-15'),priority_path = 'DESCENDING',max_cloud = 100,max_snow = 100,month_span = 1,retry_days=0)
# Out:
#  ◍◍Finding S2
#  ◍Single scene coverege was found!
#  ◍◍Finding S1
# mean s2 date:  2021-07-31
# final date range:   2021-06-30 2021-08-31 | diff_days -> 62
# ◍checking for DESCENDING single scene
# Mosiac Covers 93.96914404374861 percent of the roi.
# Mosaic Coverege Accepted
# Mosaic Coverege Accepted
#  ◍Collection Found!

# %%
sen1_print(s1_col.sort('system:time_start'))
# Out:
# <style type="text/css">
# #T_b6f76 th {
#   text-align: left;
# }
# #T_b6f76_row0_col0, #T_b6f76_row0_col1, #T_b6f76_row0_col2, #T_b6f76_row0_col3, #T_b6f76_row0_col4, #T_b6f76_row0_col5, #T_b6f76_row0_col6, #T_b6f76_row0_col7, #T_b6f76_row0_col8, #T_b6f76_row0_col9, #T_b6f76_row0_col10, #T_b6f76_row1_col0, #T_b6f76_row1_col1, #T_b6f76_row1_col2, #T_b6f76_row1_col3, #T_b6f76_row1_col4, #T_b6f76_row1_col5, #T_b6f76_row1_col6, #T_b6f76_row1_col7, #T_b6f76_row1_col8, #T_b6f76_row1_col9, #T_b6f76_row1_col10, #T_b6f76_row2_col0, #T_b6f76_row2_col1, #T_b6f76_row2_col2, #T_b6f76_row2_col3, #T_b6f76_row2_col4, #T_b6f76_row2_col5, #T_b6f76_row2_col6, #T_b6f76_row2_col7, #T_b6f76_row2_col8, #T_b6f76_row2_col9, #T_b6f76_row2_col10, #T_b6f76_row3_col0, #T_b6f76_row3_col1, #T_b6f76_row3_col2, #T_b6f76_row3_col3, #T_b6f76_row3_col4, #T_b6f76_row3_col5, #T_b6f76_row3_col6, #T_b6f76_row3_col7, #T_b6f76_row3_col8, #T_b6f76_row3_col9, #T_b6f76_row3_col10, #T_b6f76_row4_col0, #T_b6f76_row4_col1, #T_b6f76_row4_col2, #T_b6f76_row4_col3, #T_b6f76_row4_col4, #T_b6f76_row4_col5, #T_b6f76_row4_col6, #T_b6f76_row4_col7, #T_b6f76_row4_col8, #T_b6f76_row4_col9, #T_b6f76_row4_col10 {
#   text-align: left;
# }
# </style>
# <table id="T_b6f76">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b6f76_level0_col0" class="col_heading level0 col0" >Property</th>
#       <th id="T_b6f76_level0_col1" class="col_heading level0 col1" >0</th>
#       <th id="T_b6f76_level0_col2" class="col_heading level0 col2" >1</th>
#       <th id="T_b6f76_level0_col3" class="col_heading level0 col3" >2</th>
#       <th id="T_b6f76_level0_col4" class="col_heading level0 col4" >3</th>
#       <th id="T_b6f76_level0_col5" class="col_heading level0 col5" >4</th>
#       <th id="T_b6f76_level0_col6" class="col_heading level0 col6" >5</th>
#       <th id="T_b6f76_level0_col7" class="col_heading level0 col7" >6</th>
#       <th id="T_b6f76_level0_col8" class="col_heading level0 col8" >7</th>
#       <th id="T_b6f76_level0_col9" class="col_heading level0 col9" >8</th>
#       <th id="T_b6f76_level0_col10" class="col_heading level0 col10" >9</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b6f76_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b6f76_row0_col0" class="data row0 col0" >system:time_start</td>
#       <td id="T_b6f76_row0_col1" class="data row0 col1" >2021-07-02</td>
#       <td id="T_b6f76_row0_col2" class="data row0 col2" >2021-07-08</td>
#       <td id="T_b6f76_row0_col3" class="data row0 col3" >2021-07-14</td>
#       <td id="T_b6f76_row0_col4" class="data row0 col4" >2021-07-20</td>
#       <td id="T_b6f76_row0_col5" class="data row0 col5" >2021-07-26</td>
#       <td id="T_b6f76_row0_col6" class="data row0 col6" >2021-08-01</td>
#       <td id="T_b6f76_row0_col7" class="data row0 col7" >2021-08-07</td>
#       <td id="T_b6f76_row0_col8" class="data row0 col8" >2021-08-13</td>
#       <td id="T_b6f76_row0_col9" class="data row0 col9" >2021-08-19</td>
#       <td id="T_b6f76_row0_col10" class="data row0 col10" >2021-08-25</td>
#     </tr>
#     <tr>
#       <th id="T_b6f76_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b6f76_row1_col0" class="data row1 col0" >platform_number</td>
#       <td id="T_b6f76_row1_col1" class="data row1 col1" >B</td>
#       <td id="T_b6f76_row1_col2" class="data row1 col2" >A</td>
#       <td id="T_b6f76_row1_col3" class="data row1 col3" >B</td>
#       <td id="T_b6f76_row1_col4" class="data row1 col4" >A</td>
#       <td id="T_b6f76_row1_col5" class="data row1 col5" >B</td>
#       <td id="T_b6f76_row1_col6" class="data row1 col6" >A</td>
#       <td id="T_b6f76_row1_col7" class="data row1 col7" >B</td>
#       <td id="T_b6f76_row1_col8" class="data row1 col8" >A</td>
#       <td id="T_b6f76_row1_col9" class="data row1 col9" >B</td>
#       <td id="T_b6f76_row1_col10" class="data row1 col10" >A</td>
#     </tr>
#     <tr>
#       <th id="T_b6f76_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_b6f76_row2_col0" class="data row2 col0" >relativeOrbitNumber_start</td>
#       <td id="T_b6f76_row2_col1" class="data row2 col1" >110</td>
#       <td id="T_b6f76_row2_col2" class="data row2 col2" >110</td>
#       <td id="T_b6f76_row2_col3" class="data row2 col3" >110</td>
#       <td id="T_b6f76_row2_col4" class="data row2 col4" >110</td>
#       <td id="T_b6f76_row2_col5" class="data row2 col5" >110</td>
#       <td id="T_b6f76_row2_col6" class="data row2 col6" >110</td>
#       <td id="T_b6f76_row2_col7" class="data row2 col7" >110</td>
#       <td id="T_b6f76_row2_col8" class="data row2 col8" >110</td>
#       <td id="T_b6f76_row2_col9" class="data row2 col9" >110</td>
#       <td id="T_b6f76_row2_col10" class="data row2 col10" >110</td>
#     </tr>
#     <tr>
#       <th id="T_b6f76_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_b6f76_row3_col0" class="data row3 col0" >orbitProperties_pass</td>
#       <td id="T_b6f76_row3_col1" class="data row3 col1" >DESCENDING</td>
#       <td id="T_b6f76_row3_col2" class="data row3 col2" >DESCENDING</td>
#       <td id="T_b6f76_row3_col3" class="data row3 col3" >DESCENDING</td>
#       <td id="T_b6f76_row3_col4" class="data row3 col4" >DESCENDING</td>
#       <td id="T_b6f76_row3_col5" class="data row3 col5" >DESCENDING</td>
#       <td id="T_b6f76_row3_col6" class="data row3 col6" >DESCENDING</td>
#       <td id="T_b6f76_row3_col7" class="data row3 col7" >DESCENDING</td>
#       <td id="T_b6f76_row3_col8" class="data row3 col8" >DESCENDING</td>
#       <td id="T_b6f76_row3_col9" class="data row3 col9" >DESCENDING</td>
#       <td id="T_b6f76_row3_col10" class="data row3 col10" >DESCENDING</td>
#     </tr>
#     <tr>
#       <th id="T_b6f76_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_b6f76_row4_col0" class="data row4 col0" >cycleNumber</td>
#       <td id="T_b6f76_row4_col1" class="data row4 col1" >164</td>
#       <td id="T_b6f76_row4_col2" class="data row4 col2" >235</td>
#       <td id="T_b6f76_row4_col3" class="data row4 col3" >165</td>
#       <td id="T_b6f76_row4_col4" class="data row4 col4" >236</td>
#       <td id="T_b6f76_row4_col5" class="data row4 col5" >166</td>
#       <td id="T_b6f76_row4_col6" class="data row4 col6" >237</td>
#       <td id="T_b6f76_row4_col7" class="data row4 col7" >167</td>
#       <td id="T_b6f76_row4_col8" class="data row4 col8" >238</td>
#       <td id="T_b6f76_row4_col9" class="data row4 col9" >168</td>
#       <td id="T_b6f76_row4_col10" class="data row4 col10" >239</td>
#     </tr>
#   </tbody>
# </table>

# %%
sen2_print(s2_col.sort('system:time_start'))
# Out:
# <style type="text/css">
# #T_dafaf th {
#   text-align: left;
# }
# #T_dafaf_row0_col0, #T_dafaf_row0_col1, #T_dafaf_row0_col2, #T_dafaf_row0_col3, #T_dafaf_row0_col4, #T_dafaf_row0_col5, #T_dafaf_row0_col6, #T_dafaf_row0_col7, #T_dafaf_row0_col8, #T_dafaf_row0_col9, #T_dafaf_row0_col10, #T_dafaf_row0_col11, #T_dafaf_row0_col12, #T_dafaf_row1_col0, #T_dafaf_row1_col1, #T_dafaf_row1_col2, #T_dafaf_row1_col3, #T_dafaf_row1_col4, #T_dafaf_row1_col5, #T_dafaf_row1_col6, #T_dafaf_row1_col7, #T_dafaf_row1_col8, #T_dafaf_row1_col9, #T_dafaf_row1_col10, #T_dafaf_row1_col11, #T_dafaf_row1_col12, #T_dafaf_row2_col0, #T_dafaf_row2_col1, #T_dafaf_row2_col2, #T_dafaf_row2_col3, #T_dafaf_row2_col4, #T_dafaf_row2_col5, #T_dafaf_row2_col6, #T_dafaf_row2_col7, #T_dafaf_row2_col8, #T_dafaf_row2_col9, #T_dafaf_row2_col10, #T_dafaf_row2_col11, #T_dafaf_row2_col12, #T_dafaf_row3_col0, #T_dafaf_row3_col1, #T_dafaf_row3_col2, #T_dafaf_row3_col3, #T_dafaf_row3_col4, #T_dafaf_row3_col5, #T_dafaf_row3_col6, #T_dafaf_row3_col7, #T_dafaf_row3_col8, #T_dafaf_row3_col9, #T_dafaf_row3_col10, #T_dafaf_row3_col11, #T_dafaf_row3_col12, #T_dafaf_row4_col0, #T_dafaf_row4_col1, #T_dafaf_row4_col2, #T_dafaf_row4_col3, #T_dafaf_row4_col4, #T_dafaf_row4_col5, #T_dafaf_row4_col6, #T_dafaf_row4_col7, #T_dafaf_row4_col8, #T_dafaf_row4_col9, #T_dafaf_row4_col10, #T_dafaf_row4_col11, #T_dafaf_row4_col12, #T_dafaf_row5_col0, #T_dafaf_row5_col1, #T_dafaf_row5_col2, #T_dafaf_row5_col3, #T_dafaf_row5_col4, #T_dafaf_row5_col5, #T_dafaf_row5_col6, #T_dafaf_row5_col7, #T_dafaf_row5_col8, #T_dafaf_row5_col9, #T_dafaf_row5_col10, #T_dafaf_row5_col11, #T_dafaf_row5_col12, #T_dafaf_row6_col0, #T_dafaf_row6_col1, #T_dafaf_row6_col2, #T_dafaf_row6_col3, #T_dafaf_row6_col4, #T_dafaf_row6_col5, #T_dafaf_row6_col6, #T_dafaf_row6_col7, #T_dafaf_row6_col8, #T_dafaf_row6_col9, #T_dafaf_row6_col10, #T_dafaf_row6_col11, #T_dafaf_row6_col12, #T_dafaf_row7_col0, #T_dafaf_row7_col1, #T_dafaf_row7_col2, #T_dafaf_row7_col3, #T_dafaf_row7_col4, #T_dafaf_row7_col5, #T_dafaf_row7_col6, #T_dafaf_row7_col7, #T_dafaf_row7_col8, #T_dafaf_row7_col9, #T_dafaf_row7_col10, #T_dafaf_row7_col11, #T_dafaf_row7_col12, #T_dafaf_row8_col0, #T_dafaf_row8_col1, #T_dafaf_row8_col2, #T_dafaf_row8_col3, #T_dafaf_row8_col4, #T_dafaf_row8_col5, #T_dafaf_row8_col6, #T_dafaf_row8_col7, #T_dafaf_row8_col8, #T_dafaf_row8_col9, #T_dafaf_row8_col10, #T_dafaf_row8_col11, #T_dafaf_row8_col12, #T_dafaf_row9_col0, #T_dafaf_row9_col1, #T_dafaf_row9_col2, #T_dafaf_row9_col3, #T_dafaf_row9_col4, #T_dafaf_row9_col5, #T_dafaf_row9_col6, #T_dafaf_row9_col7, #T_dafaf_row9_col8, #T_dafaf_row9_col9, #T_dafaf_row9_col10, #T_dafaf_row9_col11, #T_dafaf_row9_col12, #T_dafaf_row10_col0, #T_dafaf_row10_col1, #T_dafaf_row10_col2, #T_dafaf_row10_col3, #T_dafaf_row10_col4, #T_dafaf_row10_col5, #T_dafaf_row10_col6, #T_dafaf_row10_col7, #T_dafaf_row10_col8, #T_dafaf_row10_col9, #T_dafaf_row10_col10, #T_dafaf_row10_col11, #T_dafaf_row10_col12, #T_dafaf_row11_col0, #T_dafaf_row11_col1, #T_dafaf_row11_col2, #T_dafaf_row11_col3, #T_dafaf_row11_col4, #T_dafaf_row11_col5, #T_dafaf_row11_col6, #T_dafaf_row11_col7, #T_dafaf_row11_col8, #T_dafaf_row11_col9, #T_dafaf_row11_col10, #T_dafaf_row11_col11, #T_dafaf_row11_col12, #T_dafaf_row12_col0, #T_dafaf_row12_col1, #T_dafaf_row12_col2, #T_dafaf_row12_col3, #T_dafaf_row12_col4, #T_dafaf_row12_col5, #T_dafaf_row12_col6, #T_dafaf_row12_col7, #T_dafaf_row12_col8, #T_dafaf_row12_col9, #T_dafaf_row12_col10, #T_dafaf_row12_col11, #T_dafaf_row12_col12, #T_dafaf_row13_col0, #T_dafaf_row13_col1, #T_dafaf_row13_col2, #T_dafaf_row13_col3, #T_dafaf_row13_col4, #T_dafaf_row13_col5, #T_dafaf_row13_col6, #T_dafaf_row13_col7, #T_dafaf_row13_col8, #T_dafaf_row13_col9, #T_dafaf_row13_col10, #T_dafaf_row13_col11, #T_dafaf_row13_col12, #T_dafaf_row14_col0, #T_dafaf_row14_col1, #T_dafaf_row14_col2, #T_dafaf_row14_col3, #T_dafaf_row14_col4, #T_dafaf_row14_col5, #T_dafaf_row14_col6, #T_dafaf_row14_col7, #T_dafaf_row14_col8, #T_dafaf_row14_col9, #T_dafaf_row14_col10, #T_dafaf_row14_col11, #T_dafaf_row ...
#   text-align: left;
# }
# </style>
# <table id="T_dafaf">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_dafaf_level0_col0" class="col_heading level0 col0" >Property</th>
#       <th id="T_dafaf_level0_col1" class="col_heading level0 col1" >0</th>
#       <th id="T_dafaf_level0_col2" class="col_heading level0 col2" >1</th>
#       <th id="T_dafaf_level0_col3" class="col_heading level0 col3" >2</th>
#       <th id="T_dafaf_level0_col4" class="col_heading level0 col4" >3</th>
#       <th id="T_dafaf_level0_col5" class="col_heading level0 col5" >4</th>
#       <th id="T_dafaf_level0_col6" class="col_heading level0 col6" >5</th>
#       <th id="T_dafaf_level0_col7" class="col_heading level0 col7" >6</th>
#       <th id="T_dafaf_level0_col8" class="col_heading level0 col8" >7</th>
#       <th id="T_dafaf_level0_col9" class="col_heading level0 col9" >8</th>
#       <th id="T_dafaf_level0_col10" class="col_heading level0 col10" >9</th>
#       <th id="T_dafaf_level0_col11" class="col_heading level0 col11" >10</th>
#       <th id="T_dafaf_level0_col12" class="col_heading level0 col12" >11</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dafaf_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_dafaf_row0_col0" class="data row0 col0" >system:time_start</td>
#       <td id="T_dafaf_row0_col1" class="data row0 col1" >2021-07-17</td>
#       <td id="T_dafaf_row0_col2" class="data row0 col2" >2021-07-19</td>
#       <td id="T_dafaf_row0_col3" class="data row0 col3" >2021-07-22</td>
#       <td id="T_dafaf_row0_col4" class="data row0 col4" >2021-07-24</td>
#       <td id="T_dafaf_row0_col5" class="data row0 col5" >2021-07-27</td>
#       <td id="T_dafaf_row0_col6" class="data row0 col6" >2021-07-29</td>
#       <td id="T_dafaf_row0_col7" class="data row0 col7" >2021-08-01</td>
#       <td id="T_dafaf_row0_col8" class="data row0 col8" >2021-08-03</td>
#       <td id="T_dafaf_row0_col9" class="data row0 col9" >2021-08-06</td>
#       <td id="T_dafaf_row0_col10" class="data row0 col10" >2021-08-08</td>
#       <td id="T_dafaf_row0_col11" class="data row0 col11" >2021-08-11</td>
#       <td id="T_dafaf_row0_col12" class="data row0 col12" >2021-08-13</td>
#     </tr>
#     <tr>
#       <th id="T_dafaf_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_dafaf_row1_col0" class="data row1 col0" >roi_cloud_cover</td>
#       <td id="T_dafaf_row1_col1" class="data row1 col1" >94.482621</td>
#       <td id="T_dafaf_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_dafaf_row1_col3" class="data row1 col3" >0</td>
#       <td id="T_dafaf_row1_col4" class="data row1 col4" >92.553023</td>
#       <td id="T_dafaf_row1_col5" class="data row1 col5" >94.494000</td>
#       <td id="T_dafaf_row1_col6" class="data row1 col6" >69.558007</td>
#       <td id="T_dafaf_row1_col7" class="data row1 col7" >34.397699</td>
#       <td id="T_dafaf_row1_col8" class="data row1 col8" >94.494000</td>
#       <td id="T_dafaf_row1_col9" class="data row1 col9" >94.494000</td>
#       <td id="T_dafaf_row1_col10" class="data row1 col10" >43.637724</td>
#       <td id="T_dafaf_row1_col11" class="data row1 col11" >45.506843</td>
#       <td id="T_dafaf_row1_col12" class="data row1 col12" >0.111473</td>
#     </tr>
#     <tr>
#       <th id="T_dafaf_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_dafaf_row2_col0" class="data row2 col0" >CLOUDY_PIXEL_PERCENTAGE</td>
#       <td id="T_dafaf_row2_col1" class="data row2 col1" >91.437759</td>
#       <td id="T_dafaf_row2_col2" class="data row2 col2" >2.355076</td>
#       <td id="T_dafaf_row2_col3" class="data row2 col3" >0.408007</td>
#       <td id="T_dafaf_row2_col4" class="data row2 co

# %%
class Bold_Background:
    BLACK = '\033[1;40m'
    RED = '\033[1;41m'
    GREEN = '\033[1;42m'
    YELLOW = '\033[1;43m'
    BLUE = '\033[1;44m'
    PURPLE = '\033[1;45m'
    CYAN = '\033[1;46m'
    WHITE = '\033[1;47m'

# %%
print(TextColors.HIGH_INTENSITY_BACKGROUNDs.BLUE,"HELLO",'\033[0m')
print(TextColors.BOLD_BAKGROUNDs.PURPLE,"HELLO",'\033[0m')
print(TextColors.HIGH_INTENSITYs.BLUE,"HELLO",'\033[0m')
print(TextColors.BLACK_TEXT_WIHT_BACKGROUNDs.GREEN,"HELLO",'\033[0m')


print('\033[48;2;50;50;100m',"HELLO",'\033[0m')


print('\033[38;2;165;165;0m',"HELLO",'\033[0m')
# Out:
#  HELLO
#  HELLO
#  HELLO
#  HELLO
#  HELLO
#  HELLO

# %%
TextColors.BOLDs.GREEN
# Out:
# '\x1b'

# %%
import numpy as np

def divide_image(image):
    height, width, _ = image.shape
    patch_size = 256
    patches = []
    for i in range(0, height, patch_size):
        for j in range(0, width, patch_size):
            patch = image[i:i+patch_size, j:j+patch_size]
            if patch.shape[0] == patch_size and patch.shape[1] == patch_size:
                patches.append(patch)
    return np.array(patches)

# %%
min_left_out = float('inf')
min_left_out
# Out:
# inf

# %% [markdown]
# # Testing best overlap

# %%
import numpy as np
def divide_image(img):

    # Get the width and height of the input image
    width, height = img.shape

    # Initialize variables to store the best overlap value and the minimum number of pixels left out
    best_overlap = None
    min_left_out = float('inf')

    # Try different overlap values
    for overlap in range(1, 256):
        # Calculate the number of patches needed in both the x and y directions with the current overlap value
        x_patches = (width - overlap) // (256 - overlap)
        y_patches = (height - overlap) // (256 - overlap)

        # Calculate the total number of pixels left out with the current overlap value
        left_out = (width - (x_patches * 256 - (x_patches - 1) * overlap)) * (height - (y_patches * 256 - (y_patches - 1) * overlap))

        # Check if the current overlap value is better than the previous best overlap value
        if left_out < min_left_out:
            best_overlap = overlap
            min_left_out = left_out

    # Calculate the number of patches needed in both the x and y directions with the best overlap value
    x_patches = (width - best_overlap) // (256 - best_overlap)
    y_patches = (height - best_overlap) // (256 - best_overlap)

    # Loop through all the patches and extract them from the input image
    patch_stack = []
    for y in range(y_patches):
        for x in range(x_patches):
            left = x * (256 - best_overlap)
            top = y * (256 - best_overlap)
            right = left + 256
            bottom = top + 256
            patch = img[left:right, top:bottom]
            patch_stack.append(patch)
            return patch_stack
            # do something with the patch here, like save it to a new file or process it further
            
test_image = np.random.randint(0, 255, size=(765, 787), dtype=np.uint8)
patches = divide_image(test_image)
len(patches)
# Out:
# 1

# %% [markdown]
# ## Visuallizing the `SCL` and `QA60` Cloud and Shadow masks

# %%
import ee
import geemap
from utils.ee_utils import *
from utils.utils import *

# %%
ee.Initialize()
Map = geemap.Map()

# %%
from rois import ROIS
rois = ROIS()
troi = rois.hongkong

# %%
s2 = get_s2(('2019-08-07','2019-09-07'), troi, max_cloud = 50)
sen2_print(s2)
# Out:
#  ◍◍Finding S2
#  ◍Single scene coverege was found!
# <style type="text/css">
# #T_f923c th {
#   text-align: left;
# }
# #T_f923c_row0_col0, #T_f923c_row0_col1, #T_f923c_row0_col2, #T_f923c_row0_col3, #T_f923c_row0_col4, #T_f923c_row0_col5, #T_f923c_row0_col6, #T_f923c_row1_col0, #T_f923c_row1_col1, #T_f923c_row1_col2, #T_f923c_row1_col3, #T_f923c_row1_col4, #T_f923c_row1_col5, #T_f923c_row1_col6, #T_f923c_row2_col0, #T_f923c_row2_col1, #T_f923c_row2_col2, #T_f923c_row2_col3, #T_f923c_row2_col4, #T_f923c_row2_col5, #T_f923c_row2_col6, #T_f923c_row3_col0, #T_f923c_row3_col1, #T_f923c_row3_col2, #T_f923c_row3_col3, #T_f923c_row3_col4, #T_f923c_row3_col5, #T_f923c_row3_col6, #T_f923c_row4_col0, #T_f923c_row4_col1, #T_f923c_row4_col2, #T_f923c_row4_col3, #T_f923c_row4_col4, #T_f923c_row4_col5, #T_f923c_row4_col6, #T_f923c_row5_col0, #T_f923c_row5_col1, #T_f923c_row5_col2, #T_f923c_row5_col3, #T_f923c_row5_col4, #T_f923c_row5_col5, #T_f923c_row5_col6, #T_f923c_row6_col0, #T_f923c_row6_col1, #T_f923c_row6_col2, #T_f923c_row6_col3, #T_f923c_row6_col4, #T_f923c_row6_col5, #T_f923c_row6_col6, #T_f923c_row7_col0, #T_f923c_row7_col1, #T_f923c_row7_col2, #T_f923c_row7_col3, #T_f923c_row7_col4, #T_f923c_row7_col5, #T_f923c_row7_col6, #T_f923c_row8_col0, #T_f923c_row8_col1, #T_f923c_row8_col2, #T_f923c_row8_col3, #T_f923c_row8_col4, #T_f923c_row8_col5, #T_f923c_row8_col6, #T_f923c_row9_col0, #T_f923c_row9_col1, #T_f923c_row9_col2, #T_f923c_row9_col3, #T_f923c_row9_col4, #T_f923c_row9_col5, #T_f923c_row9_col6, #T_f923c_row10_col0, #T_f923c_row10_col1, #T_f923c_row10_col2, #T_f923c_row10_col3, #T_f923c_row10_col4, #T_f923c_row10_col5, #T_f923c_row10_col6, #T_f923c_row11_col0, #T_f923c_row11_col1, #T_f923c_row11_col2, #T_f923c_row11_col3, #T_f923c_row11_col4, #T_f923c_row11_col5, #T_f923c_row11_col6, #T_f923c_row12_col0, #T_f923c_row12_col1, #T_f923c_row12_col2, #T_f923c_row12_col3, #T_f923c_row12_col4, #T_f923c_row12_col5, #T_f923c_row12_col6, #T_f923c_row13_col0, #T_f923c_row13_col1, #T_f923c_row13_col2, #T_f923c_row13_col3, #T_f923c_row13_col4, #T_f923c_row13_col5, #T_f923c_row13_col6, #T_f923c_row14_col0, #T_f923c_row14_col1, #T_f923c_row14_col2, #T_f923c_row14_col3, #T_f923c_row14_col4, #T_f923c_row14_col5, #T_f923c_row14_col6, #T_f923c_row15_col0, #T_f923c_row15_col1, #T_f923c_row15_col2, #T_f923c_row15_col3, #T_f923c_row15_col4, #T_f923c_row15_col5, #T_f923c_row15_col6 {
#   text-align: left;
# }
# </style>
# <table id="T_f923c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f923c_level0_col0" class="col_heading level0 col0" >Property</th>
#       <th id="T_f923c_level0_col1" class="col_heading level0 col1" >0</th>
#       <th id="T_f923c_level0_col2" class="col_heading level0 col2" >1</th>
#       <th id="T_f923c_level0_col3" class="col_heading level0 col3" >2</th>
#       <th id="T_f923c_level0_col4" class="col_heading level0 col4" >3</th>
#       <th id="T_f923c_level0_col5" class="col_heading level0 col5" >4</th>
#       <th id="T_f923c_level0_col6" class="col_heading level0 col6" >5</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f923c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f923c_row0_col0" class="data row0 col0" >system:time_start</td>
#       <td id="T_f923c_row0_col1" class="data row0 col1" >2019-08-08</td>
#       <td id="T_f923c_row0_col2" class="data row0 col2" >2019-08-08</td>
#       <td id="T_f923c_row0_col3" class="data row0 col3" >2019-08-13</td>
#       <td id="T_f923c_row0_col4" class="data row0 col4" >2019-08-13</td>
#       <td id="T_f923c_row0_col5" class="data row0 col5" >2019-08-28</td>
#       <td id="T_f923c_row0_col6" class="data row0 col6" >2019-08-28</td>
#     </tr>
#     <tr>
#       <th id="T_f923c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f923c_row1_col0" class="data row1 col0" >roi_cloud_cover</td>
#       <td id="T_f923c_row1_col1" class="data row1 col1" >33.550545</td>
#       <td id="T_f923c_row1_col2" class="data row1 col2" >33.729854</td>
#       <td id="T_f923c_row1_col3" class="data row1 col3" >25.971853</td>
#       <td id="T_f923c_row1_col4" class="data row1 col4" >27.941887</td>
#       <td id="T_f923c_row1_col5" class="data row1 col5" >39.512667</td>
#       <td id="T_f923c_row1_col6" class="data row1 col6" >40.027301</td>
#     </tr>
#     <tr>
#       <th id="T_f923c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f923c_row2_col0" class="data row2 col0" >CLOUDY_PIXEL_PERCENTAGE</td>
#       <td id="T_f923c_row2_col1" class="data row2 col1" >8.778919</td>
#       <td id="T_f923c_row2_col2" class="data row2 col2" >10.971131</td>
#       <td id="T_f923c_row2_col3" class="data row2 col3" >30.368852</td>
#       <td id="T_f923c_row2_col4" class="data row2 col4" >34.400475</td>
#       <td id="T_f923c_row2_col5" class="data row2 col5" >99.965189</td>
#       <td id="T_f923c_row2_col6" class="data row2 col6" >99.930996</td>
#     </tr>
#     <tr>
#       <th id="T_f923c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_f923c_row3_col0" class="data row3 col0" >CLOUD_SHADOW_PERCENTAGE</td>
#       <td id="T_f923c_row3_col1" class="data row3 col1" >0.262485</td>
#       <td id="T_f923c_row3_col2" class="data row3 col2" >0.355703</td>
#       <td id="T_f923c_row3_col3" class="data row3 col3" >0.708737</td>
#       <td id="T_f923c_row3_col4" class="data row3 col4" >0.835016</td>
#       <td id="T_f923c_row3_col5" class="data row3 col5" >0</td>
#       <td id="T_f923c_row3_col6" class="data row3 col6" >0</td>
#     </tr>
#     <tr>
#       <th id="T_f923c_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_f923c_row4_col0" class="data row4 col0" >VEGETATION_PERCENTAGE</td>
#       <td id="T_f923c_row4_col1" class="data row4 col1" >12.366406</td>
#       <td id="T_f923c_row4_col2" class="data row4 col2" >12.262448</td>
#       <td id="T_f923c_row4_col3" class="data row4 col3" >10.735075</td>
#       <td id="T_f923c_row4_col4" class="data row4 col4" >10.913491</td>
#       <td id="T_f923c_row4_col5" class="data row4 col5" >0.006489</td>
#       <td id="T_f923c_row4_col6" class="data row4 col6" >0</td>
#     </tr>
#     <tr>
#       <th id="T_f923c_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_f923c_row5_col0" class="data row5 col0" >NOT_VEGETATED_PERCENTAGE</td>
#       <td id="T_f923c_row5_col1" class="data row5 col1" >5.642653</td>
#       <td id="T_f923c_row5_col2" class="data row5 col2" >5.222380</td>
#       <td id="T_f923c_row5_col3" class="data row5 col3" >3.864992</td>
#       <td id="T_f923c_row5_col4" class="data row5 col4" >2.875908</td>
#       <td id="T_f923c_row5_col5" class="data row5 col5" >0.000041</td>
#       <td id="T_f923c_row5_col6" class="data row5 col6" >0.000025</td>
#     </tr>
#     <tr>
#       <th id="T_f923c_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_f923c_row6_col0" class="data row6 col0" >CLOUD_COVERAGE_ASSESSMENT</td>
#       <td id="T_f923c_row6_col1" class="data row6 col1" >8.778919</td>
#       <td id="T_f923c_row6_col2" class="data row6 col2" >10.971131</td>
#       <td id="T_f923c_row6_col3" class="data row6 col3" >30.368852</td>
#       <td id="T_f923c_row6_col4" class="data row6 col4" >34.400475</td>
#       <td id="T_f923c_row6_col5" class="data row6 col5" >99.965189</td>
#       <td id="T_f923c_row6_col6" class="data row6 col6" >99.930996</td>
#     </tr>
#     <tr>
#       <th id="T_f923c_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_f923c_row7_col0" class="data row7 col0" >GENERATION_TIME</td>
#       <td id="T_f923c_row7_col1" class="data row7 col1" >1565251610000</td>
#       <td id="T_f923c_row7_col2" class="data row7 col2" >1565251610000</td>
#       <td id="T_f923c_row7_col3" class="data row7 col3" >1565679838000</td>
#       <td id="T_f923c_row7_col4" class="data row7 col4" >1565679838000</td>
#       <td id="T_f923c_row7_col5" class="data row7 col5" >1566982334000</td>
#       <td id="T_f923c_row7_col6" class="data row7 col6" >1566982334000</td>
#     </tr>
#     <tr>
#       <th id="T_f923c_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_f923c_row8_

# %%
s2_img = s2.first().clip(troi)

scl = s2_img.select('SCL')
cloud_high = scl.eq(9)
cloud_med = scl.eq(8)
cloud_low = scl.eq(7)
shadow_mask = scl.eq(3)
dark_mask = scl.eq(2)

qa60 = s2_img.select('QA60')
cloud_qa = qa60.bitwiseAnd(1 << 10)


Map = geemap.Map()
Map.addLayer(s2_img, {'bands': ['B4', 'B3', 'B2'], 'min': 0, 'max': 3000}, 'Sentinel-2 Image', True)

Map.addLayer(qa60.updateMask(qa60), {'palette': '#FF11FF'}, 'Cloud QA')

Map.addLayer(cloud_high.updateMask(cloud_high), {'palette': '#1111FF'}, 'Cloud High')
Map.addLayer(cloud_med.updateMask(cloud_med), {'palette': '#111188'}, 'Cloud Med')
Map.addLayer(cloud_low.updateMask(cloud_low), {'palette': '#111155'}, 'Cloud Low')

Map.addLayer(shadow_mask.updateMask(shadow_mask), {'palette': 'green'}, 'Cloud Shadow Mask')
Map.addLayer(dark_mask.updateMask(dark_mask), {'palette': 'red'}, 'Dark pixel mask')
Map.centerObject(troi, zoom=10)
Map.addLayerControl()
Map
# Out:
# Map(center=[22.30886435509169, 114.25334930420124], controls=(WidgetControl(options=['position', 'transparent_…

# %% [markdown]
# The Sentinel-2 SCL (Scene Classification) band is used to identify different land cover types based on their spectral properties. The dark pixels in the SCL band are typically caused by shadows, water bodies, and other low reflectance surfaces that do not have a clear spectral signature that can be easily classified by the SCL algorithm.
#
# Shadows are a common cause of dark pixels in the SCL band because they result in reduced reflectance from the affected areas. This is due to the blocking of direct sunlight by nearby objects such as buildings, trees, or terrain features. Shadows can be particularly prominent in urban areas, where there are many tall buildings and other structures that cast shadows over adjacent areas.
#
# Water bodies also tend to have low reflectance in the SCL band, which can result in dark pixels. This is because water absorbs a significant amount of the incident sunlight and reflects very little of it. The SCL algorithm may also have difficulty distinguishing between water and other dark surfaces, such as shadows or low-reflectance land cover types.
#
# Other factors that can contribute to dark pixels in the SCL band include cloud shadows, vegetation shadows, and areas of low reflectance due to soil or vegetation characteristics. These factors can make it difficult for the SCL algorithm to accurately classify land cover types in affected areas.

# %%
get_mask_ones_ratio(get_cloud_mask(s2.first())[2])
# Out:
# <div><style>:root {
#   --font-color-primary: var(--jp-content-font-color0, rgba(0, 0, 0, 1));
#   --font-color-secondary: var(--jp-content-font-color2, rgba(0, 0, 0, 0.6));
#   --font-color-accent: rgba(123, 31, 162, 1);
#   --border-color: var(--jp-border-color2, #e0e0e0);
#   --background-color: var(--jp-layout-color0, white);
#   --background-color-row-even: var(--jp-layout-color1, white);
#   --background-color-row-odd: var(--jp-layout-color2, #eeeeee);
# }
#
# html[theme="dark"],
# body[data-theme="dark"],
# body.vscode-dark {
#   --font-color-primary: rgba(255, 255, 255, 1);
#   --font-color-secondary: rgba(255, 255, 255, 0.6);
#   --font-color-accent: rgb(173, 132, 190);
#   --border-color: #2e2e2e;
#   --background-color: #111111;
#   --background-color-row-even: #111111;
#   --background-color-row-odd: #313131;
# }
#
# .ee {
#   padding: 1em;
#   line-height: 1.5em;
#   min-width: 300px;
#   max-width: 1200px;
#   overflow-y: scroll;
#   max-height: 600px;
#   border: 1px solid var(--border-color);
#   font-family: monospace;
# }
#
# .ee li {
#   list-style-type: none;
# }
#
# .ee ul {
#   padding-left: 1.5em !important;
#   margin: 0;
# }
#
# .ee > ul {
#   padding-left: 0 !important;
# }
#
# .ee-open,
# .ee-shut {
#   color: var(--font-color-secondary);
#   cursor: pointer;
#   margin: 0;
# }
#
# .ee-open:hover,
# .ee-shut:hover {
#   color: var(--font-color-primary);
# }
#
# .ee-k {
#   color: var(--font-color-accent);
#   margin-right: 6px;
# }
#
# .ee-v {
#   color: var(--font-color-primary);
# }
#
# .ee-toggle {
#   display: none;
# }
#
# .ee-shut + ul {
#   display: none;
# }
#
# .ee-open + ul {
#   display: block;
# }
#
# .ee-shut::before {
#   display: inline-block;
#   content: "▼";
#   margin-right: 6px;
#   transform: rotate(-90deg);
#   transition: transform 0.2s;
# }
#
# .ee-open::before {
#   transform: rotate(0deg);
#   display: inline-block;
#   content: "▼";
#   margin-right: 6px;
#   transition: transform 0.2s;
# }
# </style><div class='ee'><ul><li><span class='ee-v'>1.0275347460691902</span></li></ul></div><script>function toggleHeader() {
#     const parent = this.parentElement;
#     parent.className = parent.className === "ee-open" ? "ee-shut" : "ee-open";
# }
#
# for (let c of document.getElementsByClassName("ee-toggle")) {
#     c.onclick = toggleHeader;
# }</script></div>

# %%
get_mask_ones_ratio(get_cloud_mask(s2.first().clip(troi))[2])
# Out:
# <div><style>:root {
#   --font-color-primary: var(--jp-content-font-color0, rgba(0, 0, 0, 1));
#   --font-color-secondary: var(--jp-content-font-color2, rgba(0, 0, 0, 0.6));
#   --font-color-accent: rgba(123, 31, 162, 1);
#   --border-color: var(--jp-border-color2, #e0e0e0);
#   --background-color: var(--jp-layout-color0, white);
#   --background-color-row-even: var(--jp-layout-color1, white);
#   --background-color-row-odd: var(--jp-layout-color2, #eeeeee);
# }
#
# html[theme="dark"],
# body[data-theme="dark"],
# body.vscode-dark {
#   --font-color-primary: rgba(255, 255, 255, 1);
#   --font-color-secondary: rgba(255, 255, 255, 0.6);
#   --font-color-accent: rgb(173, 132, 190);
#   --border-color: #2e2e2e;
#   --background-color: #111111;
#   --background-color-row-even: #111111;
#   --background-color-row-odd: #313131;
# }
#
# .ee {
#   padding: 1em;
#   line-height: 1.5em;
#   min-width: 300px;
#   max-width: 1200px;
#   overflow-y: scroll;
#   max-height: 600px;
#   border: 1px solid var(--border-color);
#   font-family: monospace;
# }
#
# .ee li {
#   list-style-type: none;
# }
#
# .ee ul {
#   padding-left: 1.5em !important;
#   margin: 0;
# }
#
# .ee > ul {
#   padding-left: 0 !important;
# }
#
# .ee-open,
# .ee-shut {
#   color: var(--font-color-secondary);
#   cursor: pointer;
#   margin: 0;
# }
#
# .ee-open:hover,
# .ee-shut:hover {
#   color: var(--font-color-primary);
# }
#
# .ee-k {
#   color: var(--font-color-accent);
#   margin-right: 6px;
# }
#
# .ee-v {
#   color: var(--font-color-primary);
# }
#
# .ee-toggle {
#   display: none;
# }
#
# .ee-shut + ul {
#   display: none;
# }
#
# .ee-open + ul {
#   display: block;
# }
#
# .ee-shut::before {
#   display: inline-block;
#   content: "▼";
#   margin-right: 6px;
#   transform: rotate(-90deg);
#   transition: transform 0.2s;
# }
#
# .ee-open::before {
#   transform: rotate(0deg);
#   display: inline-block;
#   content: "▼";
#   margin-right: 6px;
#   transition: transform 0.2s;
# }
# </style><div class='ee'><ul><li><span class='ee-v'>20.01054130620974</span></li></ul></div><script>function toggleHeader() {
#     const parent = this.parentElement;
#     parent.className = parent.className === "ee-open" ? "ee-shut" : "ee-open";
# }
#
# for (let c of document.getElementsByClassName("ee-toggle")) {
#     c.onclick = toggleHeader;
# }</script></div>

# %%
mask = scl.eq(3).Or(scl.eq(9)).Or(scl.eq(8))
get_mask_ones_ratio(mask.clip(troi))
# Out:
# <div><style>:root {
#   --font-color-primary: var(--jp-content-font-color0, rgba(0, 0, 0, 1));
#   --font-color-secondary: var(--jp-content-font-color2, rgba(0, 0, 0, 0.6));
#   --font-color-accent: rgba(123, 31, 162, 1);
#   --border-color: var(--jp-border-color2, #e0e0e0);
#   --background-color: var(--jp-layout-color0, white);
#   --background-color-row-even: var(--jp-layout-color1, white);
#   --background-color-row-odd: var(--jp-layout-color2, #eeeeee);
# }
#
# html[theme="dark"],
# body[data-theme="dark"],
# body.vscode-dark {
#   --font-color-primary: rgba(255, 255, 255, 1);
#   --font-color-secondary: rgba(255, 255, 255, 0.6);
#   --font-color-accent: rgb(173, 132, 190);
#   --border-color: #2e2e2e;
#   --background-color: #111111;
#   --background-color-row-even: #111111;
#   --background-color-row-odd: #313131;
# }
#
# .ee {
#   padding: 1em;
#   line-height: 1.5em;
#   min-width: 300px;
#   max-width: 1200px;
#   overflow-y: scroll;
#   max-height: 600px;
#   border: 1px solid var(--border-color);
#   font-family: monospace;
# }
#
# .ee li {
#   list-style-type: none;
# }
#
# .ee ul {
#   padding-left: 1.5em !important;
#   margin: 0;
# }
#
# .ee > ul {
#   padding-left: 0 !important;
# }
#
# .ee-open,
# .ee-shut {
#   color: var(--font-color-secondary);
#   cursor: pointer;
#   margin: 0;
# }
#
# .ee-open:hover,
# .ee-shut:hover {
#   color: var(--font-color-primary);
# }
#
# .ee-k {
#   color: var(--font-color-accent);
#   margin-right: 6px;
# }
#
# .ee-v {
#   color: var(--font-color-primary);
# }
#
# .ee-toggle {
#   display: none;
# }
#
# .ee-shut + ul {
#   display: none;
# }
#
# .ee-open + ul {
#   display: block;
# }
#
# .ee-shut::before {
#   display: inline-block;
#   content: "▼";
#   margin-right: 6px;
#   transform: rotate(-90deg);
#   transition: transform 0.2s;
# }
#
# .ee-open::before {
#   transform: rotate(0deg);
#   display: inline-block;
#   content: "▼";
#   margin-right: 6px;
#   transition: transform 0.2s;
# }
# </style><div class='ee'><ul><li><span class='ee-v'>33.550545056482136</span></li></ul></div><script>function toggleHeader() {
#     const parent = this.parentElement;
#     parent.className = parent.className === "ee-open" ? "ee-shut" : "ee-open";
# }
#
# for (let c of document.getElementsByClassName("ee-toggle")) {
#     c.onclick = toggleHeader;
# }</script></div>

# %%
get_mask_ones_ratio(get_cloud_mask_from_scl(s2.first().clip(troi)))
# Out:
# <div><style>:root {
#   --font-color-primary: var(--jp-content-font-color0, rgba(0, 0, 0, 1));
#   --font-color-secondary: var(--jp-content-font-color2, rgba(0, 0, 0, 0.6));
#   --font-color-accent: rgba(123, 31, 162, 1);
#   --border-color: var(--jp-border-color2, #e0e0e0);
#   --background-color: var(--jp-layout-color0, white);
#   --background-color-row-even: var(--jp-layout-color1, white);
#   --background-color-row-odd: var(--jp-layout-color2, #eeeeee);
# }
#
# html[theme="dark"],
# body[data-theme="dark"],
# body.vscode-dark {
#   --font-color-primary: rgba(255, 255, 255, 1);
#   --font-color-secondary: rgba(255, 255, 255, 0.6);
#   --font-color-accent: rgb(173, 132, 190);
#   --border-color: #2e2e2e;
#   --background-color: #111111;
#   --background-color-row-even: #111111;
#   --background-color-row-odd: #313131;
# }
#
# .ee {
#   padding: 1em;
#   line-height: 1.5em;
#   min-width: 300px;
#   max-width: 1200px;
#   overflow-y: scroll;
#   max-height: 600px;
#   border: 1px solid var(--border-color);
#   font-family: monospace;
# }
#
# .ee li {
#   list-style-type: none;
# }
#
# .ee ul {
#   padding-left: 1.5em !important;
#   margin: 0;
# }
#
# .ee > ul {
#   padding-left: 0 !important;
# }
#
# .ee-open,
# .ee-shut {
#   color: var(--font-color-secondary);
#   cursor: pointer;
#   margin: 0;
# }
#
# .ee-open:hover,
# .ee-shut:hover {
#   color: var(--font-color-primary);
# }
#
# .ee-k {
#   color: var(--font-color-accent);
#   margin-right: 6px;
# }
#
# .ee-v {
#   color: var(--font-color-primary);
# }
#
# .ee-toggle {
#   display: none;
# }
#
# .ee-shut + ul {
#   display: none;
# }
#
# .ee-open + ul {
#   display: block;
# }
#
# .ee-shut::before {
#   display: inline-block;
#   content: "▼";
#   margin-right: 6px;
#   transform: rotate(-90deg);
#   transition: transform 0.2s;
# }
#
# .ee-open::before {
#   transform: rotate(0deg);
#   display: inline-block;
#   content: "▼";
#   margin-right: 6px;
#   transition: transform 0.2s;
# }
# </style><div class='ee'><ul><li><span class='ee-v'>33.550545056482136</span></li></ul></div><script>function toggleHeader() {
#     const parent = this.parentElement;
#     parent.className = parent.className === "ee-open" ? "ee-shut" : "ee-open";
# }
#
# for (let c of document.getElementsByClassName("ee-toggle")) {
#     c.onclick = toggleHeader;
# }</script></div>

# %% [markdown]
# # Adding Dot to The Top left corner

# %%
roi = rois.hongkong
bounds = roi.bounds().getInfo()['coordinates'][0]
bounds = list(set(tuple(x) for x in bounds))
bounds = [list(x) for x in bounds]
bounds
# Out:
# [[114.27858352661131, 22.276389027850755],
#  [114.27858352661131, 22.34134341446177],
#  [114.22811508178711, 22.276389027850755],
#  [114.22811508178711, 22.34134341446177]]

# %%
smallest_coordinate = min(bounds, key=lambda coord: (coord[0], coord[1]))
smallest_coordinate
# Out:
# [114.22811508178711, 22.276389027850755]

# %%
tl_square = top_left_roi(roi)

# %%
Map = geemap.Map(zoom=12)
Map.addLayer(roi)
Map.addLayer(tl_square,{'color': '45ff45'})
Map.centerObject(roi)
Map
# Out:
# Map(center=[20, 0], controls=(WidgetControl(options=['position', 'transparent_bg'], widget=HBox(children=(Togg…

# %% [markdown]
# ### testing on real images

# %%
s2_col,s1_col = s1s2(roi,date = ('2021-07-15', '2021-08-15'),priority_path = 'DESCENDING',max_cloud = 100,max_snow = 100,month_span = 2,retry_days=0)
# Out:
#  ◍◍Finding S2
#  ◍Single scene coverege was found!
#  ◍◍Finding S1
# mean s2 date:  2021-07-29
# final date range:   2021-05-29 2021-09-29 | diff_days -> 123
# ◍checking for DESCENDING single scene
# ◍DESCENDING singe scene was not fount, checking ASCENDING single scene ...
# Mosiac Covers 95.40081697612398 percent of the roi.
# Mosaic Coverege Accepted
# Mosaic Coverege Accepted
#  ◍Collection Found!

# %%
#sen1_print(s1_col)

# %%
import ee

# %%
s1_col = ee.ImageCollection('COPERNICUS/S1_GRD') \
    .filterDate('2021-06-15', '2021-09-15') \
    .filterBounds(roi) \
    .filter(ee.Filter.eq('resolution','H')) \
    .filter(ee.Filter.eq('instrumentMode','IW'))\
    .filter(ee.Filter.eq('orbitProperties_pass','ASCENDING'))

# %%
image = s1_col.mean().clip(roi)

# %%
image.projection().getInfo()
# Out:
# {'type': 'Projection', 'crs': 'EPSG:4326', 'transform': [1, 0, 0, 0, 1, 0]}

# %%
image_with_dricetion_band = add_driection_band(image,roi)

# %%
image_with_dricetion_band.select('constant').projection().getInfo()
# Out:
# {'type': 'Projection', 'crs': 'EPSG:4326', 'transform': [1, 0, 0, 0, 1, 0]}

# %%
# Out:
# {'type': 'Projection',
#  'crs': 'EPSG:4326',
#  'transform': [8.983152841195215e-05, 0, 0, 0, -8.983152841195215e-05, 0]}

# %%
image_with_dricetion_band.bandNames().getInfo()
# Out:
# ['VV', 'VH', 'angle', 'constant']

# %%
reprojected = image.reproject({
  crs: 'EPSG:3857',
  scale: 30
})

# %%
constant_vis_params = {
    'min': 0,
    'max': 1,
    'bands': ['constant']
}

Map = geemap.Map()
Map.addLayer(image_with_dricetion_band, constant_vis_params, 'Image with constant band')
Map.centerObject(roi, zoom=10)
Map
# Out:
# Map(center=[22.30886435509169, 114.25334930420124], controls=(WidgetControl(options=['position', 'transparent_…

# %% [markdown]
# ### Downloading and checking the numpy array of the image

# %%
import pyproj

# %%
pyproj.Transformer.from_crs("EPSG:3857", "EPSG:4326", always_xy=True)
# Out:
# <Concatenated Operation Transformer: pipeline>
# Description: Inverse of Popular Visualisation Pseudo-Mercator + axis order change (2D)
# Area of Use:
# - name: World
# - bounds: (-180.0, -90.0, 180.0, 90.0)

# %%
img_w_dir = image_with_dricetion_band.select('VV','constant')
#EPSG:4326 or EPSG:3857
geemap.download_ee_image(img_w_dir, "image_with_direciton_download.tif",crs='EPSG:4326' ,scale=10,region = roi)
# Out:
# image_with_direciton_download.tif: |          | 0.00/6.52M (raw) [  0.0%] in 00:00 (eta:     ?)
# There is no STAC entry for: None

# %%
geemap.ee_export_image(img_w_dir, "image_with_direciton_export.tif", crs='EPSG:4326', scale=10, region=roi)
# Out:
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/dc0634da6bd4ad8d1148ebe77053afb7-234dc282aaccbdfef901d3dd8ea52e69:getPixels
# Please wait ...
# Data downloaded to d:\python\TemporalGAN\dataset\image_with_direciton_export.tif

# %%
from skimage import io
import matplotlib.pyplot as plt

# %%
import numpy as np
import matplotlib.pyplot as plt

def plot_bands(image):
    """
    Plots each band of an image represented as a numpy array
    """
    num_bands = image.shape[-1]
    fig, axs = plt.subplots(1, num_bands, figsize=(5*num_bands, 5))
    
    for i in range(num_bands):
        axs[i].imshow(image[:,:,i])
        axs[i].set_title(f'Band {i+1}')
        axs[i].axis('off')
    
    plt.show()

# %%
img = io.imread("image_with_direciton_download.tif")
print(img.shape)
img = reshape_array(img, channel_first = False)
print(np.max(img[:,:,0]))
plot_bands(img)
# Out:
# (2, 724, 563)
# 29.87496481337074

# %%
img = io.imread("image_with_direciton_export.tif")
print(img.shape)
img = reshape_array(img, channel_first = False)
print(img.shape)
plot_bands(img)
# Out:
# (724, 563, 2)
# (724, 563, 2)

# %%
def image_direction(driection_band: np.ndarray):
    top_left_chunk = driection_band[:driection_band.shape[0]//3,:driection_band.shape[1]//3]
    buttom_left_chunk = driection_band[-driection_band.shape[0]//3:,:driection_band.shape[1]//3]
    
    top_right_chunk = driection_band[:driection_band.shape[0]//3,-driection_band.shape[1]//3:]
    buttom_right_chunk = driection_band[-driection_band.shape[0]//3:,-driection_band.shape[1]//3:]
    
    print(np.mean(top_left_chunk),"|",np.mean(top_right_chunk))
    print(np.mean(buttom_left_chunk),"|",np.mean(buttom_right_chunk))
    
    chunck_mean_list = [np.mean(top_left_chunk),np.mean(buttom_left_chunk),np.mean(top_right_chunk),np.mean(buttom_right_chunk)]
    
    arg_max = chunck_mean_list.index(max(chunck_mean_list))
    return arg_max # 0 = top left(noflip needed), 1 = buttom left(vertical flip needed), 2 = top right(horizantal flip needed), 3 = buttom right(both flip needed)

# %%
image_direction(img[:,:,1])
# Out:
# 0.9946524064171123 | 0.0
# 0.0 | 0.0
# 0

# %%
def flip_correction(image: np.ndarray, verbose = True, return_direction_band = False):
    """
    Corrects the image if it is flipped
    """
    flip_type = image_direction(image[:,:,-1]) # passing the last band which is the direction band
    image = image[:,:,:-1] if not return_direction_band else image
    
    # flipping the image based on the flip type
    if flip_type == 0:
        print('No flip Applied') if verbose else None
        pass
    elif flip_type == 1:
        print('Vertical flip Applied') if verbose else None
        image = np.flip(image, axis=0)
    elif flip_type == 2:
        print('Horizantal flip Applied') if verbose else None
        image = np.flip(image, axis=1)
    elif flip_type == 3:
        print('Both way flip Applied') if verbose else None
        image = np.flip(image, axis=0)
        image = np.flip(image, axis=1)
    else:
        raise ValueError("Invalid flip type")
    
    return image

# %%
correct_img = flip_correction(img,return_direction_band = True)
plot_bands(correct_img)
# Out:
# 0.9946524064171123 | 0.0
# 0.0 | 0.0
# No flip Applied
